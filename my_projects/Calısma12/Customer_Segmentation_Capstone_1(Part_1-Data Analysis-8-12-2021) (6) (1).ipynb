# %% [markdown]
# ___
#
# <p style="text-align: center;"><img src="https://docs.google.com/uc?id=1lY0Uj5R04yMY3-ZppPWxqCr5pvBLYPnV" class="img-fluid" alt="CLRSWY"></p>
#
# ___

# %% [markdown]
# # WELCOME!

# %% [markdown]
# Welcome to "RFM Customer Segmentation & Cohort Analysis Project". This is the first project of the Capstone Project Series, which consists of 4 different project that contain different scenarios.
#
# This is a project which you will learn what is RFM? And how to apply RFM Analysis and Customer Segmentation using K-Means Clustering. Also you will improve your Data Cleaning, Data Visualization and Exploratory Data Analysis capabilities. On the other hand you will create Cohort and Conduct Cohort Analysis.
#
# Before diving into the project, please take a look at the determines and project structure.
#
# - **NOTE:** This tutorial assumes that you already know the basics of coding in Python and are familiar with the theory behind K-Means Clustering.

# %% [markdown]
# # #Determines
#
# Using the [Online Retail dataset](https://archive.ics.uci.edu/ml/datasets/Online+Retail) from the UCI Machine Learning Repository for exploratory data analysis, ***Customer Segmentation***, ***RFM Analysis***, ***K-Means Clustering*** and ***Cohort Analysis***.
#
# This is a transnational data set which contains all the transactions occurring between 01/12/2010 and 09/12/2011 for a UK-based and registered non-store online retail. The company mainly sells unique all-occasion gifts. Many customers of the company are wholesalers.
#
# Feature Information:
#
# **InvoiceNo**: Invoice number. *Nominal*, a 6-digit integral number uniquely assigned to each transaction. If this code starts with letter 'c', it indicates a cancellation.
# <br>
# **StockCode**: Product (item) code. *Nominal*, a 5-digit integral number uniquely assigned to each distinct product.
# <br>
# **Description**: Product (item) name. *Nominal*.
# <br>
# **Quantity**: The quantities of each product (item) per transaction. *Numeric*.
# <br>
# **InvoiceDate**: Invoice Date and time. *Numeric*, the day and time when each transaction was generated.
# <br>
# **UnitPrice**: Unit price. *Numeric*, Product price per unit in sterling.
# <br>
# **CustomerID**: Customer number. *Nominal*, a 5-digit integral number uniquely assigned to each customer.
# <br>
# **Country**: Country name. *Nominal*, the name of the country where each customer resides.
#
#
# ---
#
#
# First of all, to observe the structure of the data and missing values, you can use exploratory data analysis and data visualization techniques.
#
# You must do descriptive analysis. Because you must understand the relationship of the features to each other and clear the noise and missing values in the data. After that, the data set will be ready for RFM analysis.
#
# Before starting the RFM Analysis, you will be asked to do some analysis regarding the distribution of *Orders*, *Customers* and *Countries*. These analyzes will help the company develop its sales policies and contribute to the correct use of resources.
#
# You will notice that the UK not only has the most sales revenue, but also the most customers. So you will continue to analyze only UK transactions in the next RFM Analysis, Customer Segmentation and K-Means Clustering topics.
#
# Next, you will begin RFM Analysis, a customer segmentation technique based on customers' past purchasing behavior.
#
# By using RFM Analysis, you can enable companies to develop different approaches to different customer segments so that they can get to know their customers better, observe trends better, and increase customer retention and sales revenues.
#
# You will calculate the Recency, Frequency and Monetary values of the customers in the RFM Analysis you will make using the data consisting of UK transactions. Ultimately, you have to create an RFM table containing these values.
#
# In the Customer Segmentation section, you will create an RFM Segmentation Table where you segment your customers by using the RFM table. For example, you can label the best customer as "Big Spenders" and the lost customer as "Lost Customer".
#
# We will segment the customers ourselves based on their recency, frequency, and monetary values. But can an **unsupervised learning** model do this better for us? You will use the K-Means algorithm to find the answer to this question. Then you will compare the classification made by the algorithm with the classification you have made yourself.
#
# Before applying K-Means Clustering, you should do data pre-processing. In this context, it will be useful to examine feature correlations and distributions. In addition, the data you apply for K-Means should be normalized.
#
# On the other hand, you should inform the K-means algorithm about the number of clusters it will predict. You will also try the *** Elbow method *** and *** Silhouette Analysis *** to find the optimum number of clusters.
#
# After the above operations, you will have made cluster estimation with K-Means. You should visualize the cluster distribution by using a scatter plot. You can observe the properties of the resulting clusters with the help of the boxplot. Thus you will be able to tag clusters and interpret results.
#
# Finally, you will do Cohort Analysis with the data you used at the beginning, regardless of the analysis you have done before. Cohort analysis is a subset of behavioral analytics that takes the user data and breaks them into related groups for analysis. This analysis can further be used to do customer segmentation and track metrics like retention, churn, and lifetime value.

# %% [markdown]
# # #Project Structures
#
# - Data Cleaning & Exploratory Data Analysis
# - RFM Analysis
# - Customer Segmentation
# - Applying K-Means Clustering
# - Create Cohort and Conduct Cohort Analysis

# %% [markdown]
# # #Tasks
#
# #### 1. Data Cleaning & Exploratory Data Analysis
#
# - Import Modules, Load Data & Data Review
# - Follow the Steps Below
#
#     *i. Take a look at relationships between InvoiceNo, Quantity and UnitPrice columns.*
#
#     *ii. What does the letter "C" in the invoiceno column mean?*
#
#     *iii. Handling Missing Values*
#
#     *iv. Clean the Data from the Noise and Missing Values*
#
#     *v. Explore the Orders*
#
#     *vi. Explore Customers by Country*
#
#     *vii. Explore the UK Market*
#
# #### 2. RFM Analysis
#
# - Follow the steps below
#
#    *i. Import Libraries*
#
#    *ii. Review "df_uk" DataFrame (the df_uk what you create at the end of the Task 1)*
#
#    *iii. Calculate Recency*
#
#    *iv. Calculate Frequency*
#
#    *v. Calculate Monetary Values*
#
#    *vi. Create RFM Table*
#
# #### 3. Customer Segmentation with RFM Scores
# - Calculate RFM Scoring
#
#     *i. Creating the RFM Segmentation Table*
#
# - Plot RFM Segments
#
# #### 4. Applying K-Means Clustering
# - Data Pre-Processing and Exploring
#
#     *i. Define and Plot Feature Correlations*
#
#     *ii. Visualize Feature Distributions*
#
#     *iii. Data Normalization*
#
# - K-Means Implementation
#
#     *i. Define Optimal Cluster Number (K) by using "Elbow Method" and "Silhouette Analysis"*
#
#     *ii. Visualize the Clusters*
#
#     *iii. Assign the label*
#
#     *iv. Conclusion*
#
# #### 5. Create Cohort and Conduct Cohort Analysis
# - Future Engineering
#
#     *i. Extract the Month of the Purchase*
#
#     *ii. Calculating time offset in Months i.e. Cohort Index*
#
# - Create 1st Cohort: User Number & Retention Rate
#
#     *i. Pivot Cohort and Cohort Retention*
#
#     *ii. Visualize analysis of cohort 1 using seaborn and matplotlib*
#
# - Create 2nd Cohort: Average Quantity Sold
#
#     *i. Pivot Cohort and Cohort Retention*
#
#     *ii. Visualize analysis of cohort 2 using seaborn and matplotlib*
#
# - Create 3rd Cohort: Average Sales
#
#     *i. Pivot Cohort and Cohort Retention*
#
#     *ii. Visualize analysis of cohort 3 using seaborn and matplotlib*
#
# - **Note: There may be sub-tasks associated with each task, you will see them in order during the course of the work.**

# %% [markdown]
# # 1. Data Cleaning & Exploratory Data Analysis

# %% [markdown]
# <div class="alert alert-block alert-success">
#
# ## <span style=" color:Purple"> 1-Data Cleaning & Exploratory Data Analysis </span>
#
# - Import Modules, Load Data & Data Review
#
# Follow the Steps Below
#
# i. Take a look at relationships between InvoiceNo, Quantity and UnitPrice columns.
#
# ii. What does the letter "C" in the invoiceno column mean?
#
# iii. Handling Missing Values
#
# iv. Clean the Data from the Noise and Missing Values
#
# v. Explore the Orders
#
# vi. Explore Customers by Country
#
# vii. Explore the UK Market

# %% [markdown]
# ## Import Modules, Load Data & Data Review

# %%
#!pip install pyforest

# %%
import pyforest
import numpy as np
import pandas as pd
import seaborn as sns 
import matplotlib.pyplot as plt

import warnings
warnings.filterwarnings("ignore")
warnings.warn("this will not show")

# %matplotlib inline
# %matplotlib notebook

plt.rcParams["figure.figsize"] = (10,6)
# plt.rcParams['figure.dpi'] = 100

sns.set_style("whitegrid")
pd.set_option('display.float_format', lambda x: '%.3f' % x)

pd.options.display.max_rows = 100
pd.options.display.max_columns = 100

# %%
df = pd.read_excel('Online Retail.xlsx')

# %%
df.sample(10)
# Out:
#        InvoiceNo StockCode                      Description  Quantity  \
# 323767    565331     21327              SKULLS WRITING SET          1
# 380682    569828     23404       HOME SWEET HOME BLACKBOARD         1
# 224377    556517     22637            PIGGY BANK RETROSPOT          8
# 89468     543909    90120C      GREEN MURANO TWIST BRACELET         1
# 302446    563431     23145   ZINC T-LIGHT HOLDER STAR LARGE        12
# 505358    579014     23081    GREEN METAL BOX ARMY SUPPLIES         4
# 343871    566975     22382       LUNCH BAG SPACEBOY DESIGN         10
# 169010    551158     22302         COFFEE MUG PEARS  DESIGN         6
# 75904     542613     22859         EASTER TIN BUNNY BOUQUET         6
# 1444      536544     21774  DECORATIVE CATS BATHROOM BOTTLE         2
#
#                InvoiceDate  UnitPrice  CustomerID         Country
# 323767 2011-09-02 13:59:00      1.650   16674.000  United Kingdom
# 380682 2011-10-06 12:35:00      4.950   14527.000  United Kingdom
# 224377 2011-06-13 10:52:00      2.550   12481.000         Germany
# 89468  2011-02-14 12:32:00      4.150         NaN  United Kingdom
# 302446 2011-08-16 12:00:00      0.950   16266.000  United Kingdom
# 505358 2011-11-28 09:53:00      8.250   12906.000  United Kingdom
# 343871 2011-09-16 09:24:00      1.650   13599.000  United Kingdom
# 169010 2011-04-26 15:00:00      2.550   16823.000  United Kingdom
# 75904  2011-01-30 14:36:00      1.650   17431.000  United Kingdom
# 1444   2010-12-01 14:32:00      2.510         NaN  United Kingdom

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 541909 entries, 0 to 541908
# Data columns (total 8 columns):
#  #   Column       Non-Null Count   Dtype
# ---  ------       --------------   -----
#  0   InvoiceNo    541909 non-null  object
#  1   StockCode    541909 non-null  object
#  2   Description  540455 non-null  object
#  3   Quantity     541909 non-null  int64
#  4   InvoiceDate  541909 non-null  datetime64[ns]
#  5   UnitPrice    541909 non-null  float64
#  6   CustomerID   406829 non-null  float64
#  7   Country      541909 non-null  object
# dtypes: datetime64[ns](1), float64(2), int64(1), object(4)
# memory usage: 33.1+ MB

# %%
df.shape
# Out:
# (541909, 8)

# %% [markdown]
# <div class="alert alert-block alert-info">
# 👇🏻Duplicate rows bakildiginda 5258 tane var.Bunlari drop edip yola 536641 satirla devam ediyoruz.

# %%
df[df.duplicated()] # they do not seem to be duplicated , they are orders on the same invoice
# Out:
#        InvoiceNo StockCode                        Description  Quantity  \
# 517       536409     21866        UNION JACK FLAG LUGGAGE TAG         1
# 527       536409     22866      HAND WARMER SCOTTY DOG DESIGN         1
# 537       536409     22900    SET 2 TEA TOWELS I LOVE LONDON          1
# 539       536409     22111       SCOTTIE DOG HOT WATER BOTTLE         1
# 555       536412     22327  ROUND SNACK BOXES SET OF 4 SKULLS         1
# ...          ...       ...                                ...       ...
# 541675    581538     22068        BLACK PIRATE TREASURE CHEST         1
# 541689    581538     23318     BOX OF 6 MINI VINTAGE CRACKERS         1
# 541692    581538     22992             REVOLVER WOODEN RULER          1
# 541699    581538     22694                       WICKER STAR          1
# 541701    581538     23343       JUMBO BAG VINTAGE CHRISTMAS          1
#
#                InvoiceDate  UnitPrice  CustomerID         Country
# 517    2010-12-01 11:45:00      1.250   17908.000  United Kingdom
# 527    2010-12-01 11:45:00      2.100   17908.000  United Kingdom
# 537    2010-12-01 11:45:00      2.950   17908.000  United Kingdom
# 539    2010-12-01 11:45:00      4.950   17908.000  United Kingdom
# 555    2010-12-01 11:49:00      2.950   17920.000  United Kingdom
# ...                    ...        ...         ...             ...
# 541675 2011-12-09 11:34:00      0.390   14446.000  United Kingdom
# 541689 2011-12-09 11:34:00      2.490   14446.000  United Kingdom
# 541692 2011-12-09 11:34:00      1.950   14446.000  United Kingdom
# 541699 2011-12-09 11:34:00      2.100   14446.000  United Kingdom
# 541701 2011-12-09 11:34:00      2.080   14446.000  United Kingdom
#
# [5268 rows x 8 columns]

# %%
df.duplicated().sum()
# Out:
# 5268

# %%
df[(df.InvoiceNo == 536409)& (df.Description == 'UNION JACK FLAG LUGGAGE TAG')]
# Out:
#     InvoiceNo StockCode                  Description  Quantity  \
# 494    536409     21866  UNION JACK FLAG LUGGAGE TAG         1
# 517    536409     21866  UNION JACK FLAG LUGGAGE TAG         1
#
#             InvoiceDate  UnitPrice  CustomerID         Country
# 494 2010-12-01 11:45:00      1.250   17908.000  United Kingdom
# 517 2010-12-01 11:45:00      1.250   17908.000  United Kingdom

# %%
df = df.drop_duplicates()

# %%
df.shape
# Out:
# (536641, 8)

# %% [markdown]
# <div class="alert alert-block alert-info">
#
# Object type li sutunlarin unique value sayilari👇🏻

# %%
for column in df.select_dtypes('object').columns:
    print(f'Column {column} has {df[column].nunique()} unique values.')
# Out:
# Column InvoiceNo has 25900 unique values.
# Column StockCode has 4070 unique values.
# Column Description has 4223 unique values.
# Column Country has 38 unique values.

# %% [markdown]
# <div class="alert alert-block alert-info">
#
# 🔍Missing value durumuma genel bakis

# %%
df.isnull().sum()
# Out:
# InvoiceNo           0
# StockCode           0
# Description      1454
# Quantity            0
# InvoiceDate         0
# UnitPrice           0
# CustomerID     135037
# Country             0
# dtype: int64

# %%
df.describe().T
# Out:
#                 count      mean      std        min       25%       50%  \
# Quantity   536641.000     9.620  219.130 -80995.000     1.000     3.000
# UnitPrice  536641.000     4.633   97.233 -11062.060     1.250     2.080
# CustomerID 401604.000 15281.161 1714.006  12346.000 13939.000 15145.000
#
#                  75%       max
# Quantity      10.000 80995.000
# UnitPrice      4.130 38970.000
# CustomerID 16784.000 18287.000

# %% [markdown]
# ### i. Take a look at relationships between InvoiceNo, Quantity and UnitPrice columns.

# %%
df[df['InvoiceNo'] == 563557 ][['Quantity',"UnitPrice",'Description']].sample(10)
# Out:
#         Quantity  UnitPrice                          Description
# 304007        16      0.650  COLOUR GLASS T-LIGHT HOLDER HANGING
# 303991        12      2.100        CHOCOLATE THIS WAY METAL SIGN
# 303873         6      2.950        PAPER BUNTING VINTAGE PAISLEY
# 303996        24      0.830       TOILET SIGN OCCUPIED OR VACANT
# 303949        12      0.850     PACK OF 20 NAPKINS PANTRY DESIGN
# 303992        12      2.100            AREA PATROLLED METAL SIGN
# 303894        12      1.250                  HAPPY STENCIL CRAFT
# 304026         4      9.950           FAMILY PHOTO FRAME CORNICE
# 303951        12      1.450      SET OF 36 TEATIME PAPER DOILIES
# 303967        24      0.550       72 SWEETHEART FAIRY CAKE CASES

# %%
df[['Quantity',"UnitPrice"]].corr().style.background_gradient(cmap="Blues")
#Aralarinda herhangi bir corr yoktur.Invoice no object oldugu icin corr aranmaz.
# Out:
# <style  type="text/css" >
# #T_c3bd6_row0_col0,#T_c3bd6_row1_col1{
#             background-color:  #08306b;
#             color:  #f1f1f1;
#         }#T_c3bd6_row0_col1,#T_c3bd6_row1_col0{
#             background-color:  #f7fbff;
#             color:  #000000;
#         }</style><table id="T_c3bd6_" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Quantity</th>        <th class="col_heading level0 col1" >UnitPrice</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_c3bd6_level0_row0" class="row_heading level0 row0" >Quantity</th>
#                         <td id="T_c3bd6_row0_col0" class="data row0 col0" >1.000000</td>
#                         <td id="T_c3bd6_row0_col1" class="data row0 col1" >-0.001243</td>
#             </tr>
#             <tr>
#                         <th id="T_c3bd6_level0_row1" class="row_heading level0 row1" >UnitPrice</th>
#                         <td id="T_c3bd6_row1_col0" class="data row1 col0" >-0.001243</td>
#                         <td id="T_c3bd6_row1_col1" class="data row1 col1" >1.000000</td>
#             </tr>
#     </tbody></table>

# %%
df[['InvoiceNo','Quantity',"UnitPrice",'Description']].sample(15)
# Out:
#        InvoiceNo  Quantity  UnitPrice                          Description
# 436549    574170         1      8.250                  WALL ART KEEP CALM
# 116191    546220         5      3.950    SET OF 6 SPICE TINS PANTRY DESIGN
# 361834    568387         6      8.500                 RED DINER WALL CLOCK
# 164258    550637         1      2.100         CHILDREN'S APRON DOLLY GIRL
# 3428      536628         6      1.060           RETRO COFFEE MUGS ASSORTED
# 272222    560772         1      2.460   SET/10 PINK POLKADOT PARTY CANDLES
# 383773    570087         3      4.960               LUNCH BAG APPLE DESIGN
# 396934    571105         4      0.420           MINI JIGSAW GO TO THE FAIR
# 206247    554918         2      3.750    SET 6 PAPER TABLE LANTERN HEARTS
# 478691    577104         2      8.950  3 DRAWER ANTIQUE WHITE WOOD CABINET
# 241134    558191         3      2.100           FOUR HOOK  WHITE LOVEBIRDS
# 91254     544089         1      2.460        SET OF 3 HEART COOKIE CUTTERS
# 72338     542240         6      2.950    RECIPE BOX BLUE SKETCHBOOK DESIGN
# 110141    545670         4      8.500           VINTAGE UNION JACK BUNTING
# 499583    578678         1      0.390           NOEL GARLAND PAINTED ZINC

# %% [markdown]
# We see that there are negative values in the Quantity and UnitPrice columns. These are possibly canceled and returned orders. Let's check it out.

# %%
df[df.InvoiceNo.str.startswith('C', na=False)].sample(15)
# Out:
#        InvoiceNo StockCode                         Description  Quantity  \
# 45915    C540307     21645     ASSORTED TUTTI FRUTTI ROUND BOX       -24
# 144835   C548851     82483  WOOD 2 DRAWER CABINET WHITE FINISH        -1
# 394027   C570867     22708                     WRAP DOLLY GIRL       -25
# 397666   C571196     23220      REINDEER HEART DECORATION GOLD       -12
# 164828   C550709     22212          FOUR HOOK  WHITE LOVEBIRDS        -1
# 214673   C555598     22698      PINK REGENCY TEACUP AND SAUCER        -1
# 21471    C538085     82486   WOOD S/3 CABINET ANT WHITE FINISH        -1
# 273688   C560855     22899        CHILDREN'S APRON DOLLY GIRL         -1
# 89273    C543837     22698      PINK REGENCY TEACUP AND SAUCER        -1
# 397674   C571196     20725             LUNCH BAG RED RETROSPOT       -10
# 516170   C579871     20727             LUNCH BAG  BLACK SKULL.        -1
# 508006   C579192     22423            REGENCY CAKESTAND 3 TIER       -10
# 501793   C578832     22632           HAND WARMER RED RETROSPOT        -1
# 428874   C573502     23389              SPACEBOY MINI BACKPACK        -2
# 410576   C572115     22997       TRAVEL CARD WALLET UNION JACK       -22
#
#                InvoiceDate  UnitPrice  CustomerID         Country
# 45915  2011-01-06 12:58:00      1.650   15823.000  United Kingdom
# 144835 2011-04-04 13:14:00      5.950   15311.000  United Kingdom
# 394027 2011-10-12 16:17:00      0.420   12607.000             USA
# 397666 2011-10-14 12:02:00      0.830         NaN  United Kingdom
# 164828 2011-04-20 10:53:00      2.100   12997.000  United Kingdom
# 214673 2011-06-06 10:57:00      2.950   15095.000  United Kingdom
# 21471  2010-12-09 14:43:00      7.950   16350.000  United Kingdom
# 273688 2011-07-21 13:00:00      2.100   14410.000  United Kingdom
# 89273  2011-02-14 10:56:00      2.950   14431.000  United Kingdom
# 397674 2011-10-14 12:02:00      1.650         NaN  United Kingdom
# 516170 2011-11-30 16:54:00      1.650   16101.000  United Kingdom
# 508006 2011-11-28 15:43:00     12.750   12657.000          France
# 501793 2011-11-25 15:18:00      2.100   13069.000  United Kingdom
# 428874 2011-10-31 12:02:00      4.150   14808.000  United Kingdom
# 410576 2011-10-20 19:16:00      0.420   16394.000  United Kingdom

# %%
df[df['StockCode']=='D']
# Out:
#        InvoiceNo StockCode Description  Quantity         InvoiceDate  \
# 141      C536379         D    Discount        -1 2010-12-01 09:41:00
# 9038     C537164         D    Discount        -1 2010-12-05 13:21:00
# 14498    C537597         D    Discount        -1 2010-12-07 12:34:00
# 19392    C537857         D    Discount        -1 2010-12-08 16:00:00
# 31134    C538897         D    Discount        -1 2010-12-15 09:14:00
# 31135    C538897         D    Discount        -1 2010-12-15 09:14:00
# 31663    C539003         D    Discount        -1 2010-12-15 12:35:00
# 38609    C539589         D    Discount        -1 2010-12-20 13:14:00
# 44405    C540171         D    Discount        -1 2011-01-05 12:26:00
# 88032    C543752         D    Discount        -1 2011-02-11 14:12:00
# 88071    C543758         D    Discount        -1 2011-02-11 15:07:00
# 88211    C543789         D    Discount        -1 2011-02-11 17:10:00
# 89282    C543840         D    Discount        -1 2011-02-14 11:19:00
# 108071   C545476         D    Discount        -1 2011-03-03 11:05:00
# 108088   C545478         D    Discount      -720 2011-03-03 11:08:00
# 115091   C546106         D    Discount        -1 2011-03-09 12:21:00
# 140555   C548411         D    Discount        -1 2011-03-31 10:36:00
# 140795   C548462         D    Discount        -1 2011-03-31 12:11:00
# 150591   C549452         D    Discount        -1 2011-04-08 14:17:00
# 169541   C551190         D    Discount        -1 2011-04-27 10:22:00
# 169834   C551265         D    Discount        -1 2011-04-27 12:06:00
# 181009   C552423         D    Discount        -1 2011-05-09 12:44:00
# 182729   C552569         D    Discount      -240 2011-05-10 12:06:00
# 183138   C552650         D    Discount       -18 2011-05-10 14:03:00
# 192807   C553482         D    Discount        -1 2011-05-17 12:07:00
# 194727   C553665         D    Discount        -1 2011-05-18 12:16:00
# 196362   C553841         D    Discount       -48 2011-05-19 12:19:00
# 203526   C554516         D    Discount        -1 2011-05-24 16:50:00
# 214671   C555597         D    Discount        -1 2011-06-06 10:19:00
# 218253   C556037         D    Discount        -1 2011-06-08 12:37:00
# 221712   C556265         D    Discount        -1 2011-06-09 19:24:00
# 226396   C556796         D    Discount       -96 2011-06-14 14:40:00
# 227481   C556877         D    Discount        -1 2011-06-15 12:00:00
# 227705   C556904         D    Discount        -1 2011-06-15 12:56:00
# 238153   C557927         D    Discount        -1 2011-06-23 14:56:00
# 263482   C559992         D    Discount        -1 2011-07-14 12:30:00
# 273604   C560842         D    Discount        -1 2011-07-21 12:25:00
# 273935   C560869         D    Discount        -1 2011-07-21 14:32:00
# 279033   C561225         D    Discount        -1 2011-07-26 10:06:00
# 280503   C561464         D    Discount        -1 2011-07-27 12:40:00
# 295575   C562796         D    Discount        -1 2011-08-09 14:27:00
# 300951   C563225         D    Discount        -1 2011-08-14 14:35:00
# 304661   C563592         D    Discount        -1 2011-08-18 06:12:00
# 304662   C563593         D    Discount        -1 2011-08-18 06:13:00
# 313360   C564487         D    Discount        -1 2011-08-25 14:07:00
# 317545   C564812         D    Discount        -1 2011-08-30 11:45:00
# 317546   C564812         D    Discount        -1 2011-08-30 11:45:00
# 317547   C564812         D    Discount        -1 2011-08-30 11:45:00
# 317548   C564812         D    Discount        -1 2011-08-30 11:45:00
# 319865   C564909         D    Discount        -1 2011-08-31 12:29:00
# 319866   C564909         D    Discount        -1 2011-08-31 12:29:00
# 320697   C565075         D    Discount        -1 2011-08-31 17:25:00
# 320698   C565075         D    Discount        -1 2011-08-31 17:25:00
# 320704   C565078         D    Discount        -1 2011-08-31 17:45:00
# 323492   C565313         D    Discount        -1 2011-09-02 12:41:00
# 324132   C565390         D    Discount        -1 2011-09-02 16:23:00
# 332535   C566078         D    Discount        -1 2011-09-09 09:38:00
# 337787   C566475         D    Discount        -1 2011-09-12 18:26:00
# 340223   C566613         D    Discount        -1 2011-09-13 17:17:00
# 340224   C566614         D    Discount        -1 2011-09-13 17:28:00
# 354737   C567896         D    Discount        -1 2011-09-22 15:59:00
# 380685   C569829         D    Discount        -1 2011-10-06 12:37:00
# 380686   C569829         D    Discount        -1 2011-10-06 12:37:00
# 422377   C573081         D    Discount        -1 2011-10-27 14:20:00
# 436717   C574238         D    Discount        -1 2011-11-03 12:39:00
# 436718   C574238         D    Discount        -1 2011-11-03 12:39:00
# 436719   C574238         D    Discount        -1 2011-11-03 12:39:00
# 459263   C575872         D    Discount        -1 2011-11-11 12:52:00
# 465290   C576218         D    Discount        -1 2011-11-14 12:57:00
# 465548   C576244         D    Discount        -1 2011-11-14 13:40:00
# 479866   C577227         D    Discount        -1 2011-11-18 12:06:00
# 479867   C577227         D    Discount        -1 2011-11-18 12:06:00
# 479868   C577227         D    Discount        -1 2011-11-18 12:06:00
# 479869   C577227         D    Discount        -1 2011-11-18 12:06:00
# 493613   C578239         D    Discount        -1 2011-11-23 12:29:00
# 516221   C579884         D    Discount        -1 2011-11-30 17:34:00
# 516455   C579908         D    Discount        -1 2011-12-01 08:49:00
#
#         UnitPrice  CustomerID         Country
# 141        27.500   14527.000  United Kingdom
# 9038       29.290   14527.000  United Kingdom
# 14498     281.000   15498.000  United Kingdom
# 19392     267.120   17340.000  United Kingdom
# 31134       5.760   16422.000  United Kingdom
# 31135      42.500   16422.000  United Kingdom
# 31663      26.930   14527.000  United Kingdom
# 38609      13.880   14527.000  United Kingdom
# 44405      22.970   14527.000  United Kingdom
# 88032      64.270   14031.000  United Kingdom
# 88071      65.910   15299.000  United Kingdom
# 88211      84.800   17450.000  United Kingdom
# 89282      70.010   14527.000  United Kingdom
# 108071     30.380   14527.000  United Kingdom
# 108088      0.010   16422.000  United Kingdom
# 115091      9.870   14527.000  United Kingdom
# 140555    162.240   13316.000  United Kingdom
# 140795     14.520   14527.000  United Kingdom
# 150591   1867.860   17940.000  United Kingdom
# 169541    120.000   17940.000  United Kingdom
# 169834     11.760   14527.000  United Kingdom
# 181009     11.840   14527.000  United Kingdom
# 182729      0.030   12901.000  United Kingdom
# 183138      1.450   16672.000  United Kingdom
# 192807      9.840   14527.000  United Kingdom
# 194727     15.960   14527.000  United Kingdom
# 196362      0.200   16029.000  United Kingdom
# 203526     13.880   14527.000  United Kingdom
# 214671     42.000   15796.000  United Kingdom
# 218253     20.920   14527.000  United Kingdom
# 221712     28.040   16684.000  United Kingdom
# 226396      0.700   16013.000  United Kingdom
# 227481    129.900   15498.000  United Kingdom
# 227705     14.420   14527.000  United Kingdom
# 238153     10.000   16029.000  United Kingdom
# 263482     13.990   14527.000  United Kingdom
# 273604     12.150   14527.000  United Kingdom
# 273935     66.240   12830.000  United Kingdom
# 279033     45.600   16029.000  United Kingdom
# 280503     26.050   14527.000  United Kingdom
# 295575     64.000   13694.000  United Kingdom
# 300951    434.510   14911.000            EIRE
# 304661      9.600   16029.000  United Kingdom
# 304662    206.400   14646.000     Netherlands
# 313360     11.520   15838.000  United Kingdom
# 317545     16.670   14527.000  United Kingdom
# 317546     15.070   14527.000  United Kingdom
# 317547     10.060   14527.000  United Kingdom
# 317548     13.000   14527.000  United Kingdom
# 319865     66.170   15498.000  United Kingdom
# 319866     33.750   15498.000  United Kingdom
# 320697     36.300   13408.000  United Kingdom
# 320698     38.390   13408.000  United Kingdom
# 320704     57.600   16422.000  United Kingdom
# 323492     14.500   14527.000  United Kingdom
# 324132    110.430   13408.000  United Kingdom
# 332535     45.330   13137.000  United Kingdom
# 337787     20.750   14527.000  United Kingdom
# 340223     15.000   16029.000  United Kingdom
# 340224    102.240   16029.000  United Kingdom
# 354737     18.620   14527.000  United Kingdom
# 380685     16.740   14527.000  United Kingdom
# 380686     16.070   14527.000  United Kingdom
# 422377     23.270   14527.000  United Kingdom
# 436717     11.840   13408.000  United Kingdom
# 436718     39.700   13408.000  United Kingdom
# 436719     11.590   13408.000  United Kingdom
# 459263     97.140   13408.000  United Kingdom
# 465290    183.000   13694.000  United Kingdom
# 465548      6.000   18167.000  United Kingdom
# 479866     27.260   14527.000  United Kingdom
# 479867     14.880   14527.000  United Kingdom
# 479868     19.820   14527.000  United Kingdom
# 479869     16.760   14527.000  United Kingdom
# 493613     26.330   14912.000           Italy
# 516221     20.530   14527.000  United Kingdom
# 516455     28.680   14527.000  United Kingdom

# %%
df[df.InvoiceNo.str.startswith('A', na=False)]
# Out:
#        InvoiceNo StockCode      Description  Quantity         InvoiceDate  \
# 299982   A563185         B  Adjust bad debt         1 2011-08-12 14:50:00
# 299983   A563186         B  Adjust bad debt         1 2011-08-12 14:51:00
# 299984   A563187         B  Adjust bad debt         1 2011-08-12 14:52:00
#
#         UnitPrice  CustomerID         Country
# 299982  11062.060         NaN  United Kingdom
# 299983 -11062.060         NaN  United Kingdom
# 299984 -11062.060         NaN  United Kingdom

# %% [markdown]
# ### ii. What does the letter "C" in the InvoiceNo column mean?

# %% [markdown]
# If the invoice number starts with the letter "C", it means the order was cancelled. Or those who abandon their order.

# %%
df[(df['Quantity']<0) | (df['UnitPrice']<0)].sample(20)
# Out:
#        InvoiceNo  StockCode                        Description  Quantity  \
# 7292      537028      21696                                NaN      -320
# 239251   C558037  AMAZONFEE                         AMAZON FEE        -1
# 270089   C560540      22973       CHILDREN'S CIRCUS PARADE MUG        -1
# 403535   C571634          M                             Manual        -1
# 52398    C540780      21843           RED RETROSPOT CAKE STAND        -4
# 502118    578837     35833P                              check       -24
# 31938    C539031      22199           FRYING PAN RED RETROSPOT        -4
# 20469     538054     85167B                                NaN       -24
# 96387    C544557      85150      LADIES & GENTLEMEN METAL SIGN        -1
# 176770   C552020      22189            CREAM HEART CARD HOLDER        -1
# 382991   C569985      84380  SET OF 3 BUTTERFLY COOKIE CUTTERS       -12
# 214667   C555595      22652                  TRAVEL SEWING KIT        -1
# 12538    C537383      21658                 GLASS  BEURRE DISH        -1
# 304693   C563607      22729        ALARM CLOCK BAKELIKE ORANGE        -2
# 488722   C577849      23535            WALL ART BICYCLE SAFETY        -1
# 492584   C578131      23485      BOTANICAL GARDENS WALL CLOCK         -1
# 140740   C548460      21745    GAOLERS KEYS DECORATIVE GARDEN         -4
# 294277   C562709      21232     STRAWBERRY CERAMIC TRINKET BOX        -1
# 275796   C561012      23283               DOORMAT VINTAGE LEAF        -1
# 74139    C542402      22960           JAM MAKING SET WITH JARS        -2
#
#                InvoiceDate  UnitPrice  CustomerID         Country
# 7292   2010-12-03 16:36:00      0.000         NaN  United Kingdom
# 239251 2011-06-24 12:33:00   4534.240         NaN  United Kingdom
# 270089 2011-07-19 12:26:00      1.650   12415.000       Australia
# 403535 2011-10-18 11:34:00     79.200   16029.000  United Kingdom
# 52398  2011-01-11 11:19:00     10.950   14299.000  United Kingdom
# 502118 2011-11-25 15:51:00      0.000         NaN  United Kingdom
# 31938  2010-12-15 14:25:00      4.250   12647.000         Germany
# 20469  2010-12-09 13:34:00      0.000         NaN  United Kingdom
# 96387  2011-02-21 12:31:00      2.550   17422.000  United Kingdom
# 176770 2011-05-05 17:47:00      3.950   18183.000  United Kingdom
# 382991 2011-10-06 19:51:00      1.250   15365.000  United Kingdom
# 214667 2011-06-06 10:14:00      1.650   17652.000  United Kingdom
# 12538  2010-12-06 13:17:00      3.950   16550.000  United Kingdom
# 304693 2011-08-18 06:31:00      3.750   13078.000  United Kingdom
# 488722 2011-11-22 10:59:00      5.950   14534.000  United Kingdom
# 492584 2011-11-23 10:49:00     20.800   13171.000  United Kingdom
# 140740 2011-03-31 11:58:00      3.750   16801.000  United Kingdom
# 294277 2011-08-08 14:32:00      1.060   17511.000  United Kingdom
# 275796 2011-07-22 16:11:00      7.950   13098.000  United Kingdom
# 74139  2011-01-27 16:05:00      4.250   16124.000  United Kingdom

# %%
df[df['Description'].isnull()]
# Out:
#        InvoiceNo StockCode Description  Quantity         InvoiceDate  \
# 622       536414     22139         NaN        56 2010-12-01 11:52:00
# 1970      536545     21134         NaN         1 2010-12-01 14:32:00
# 1971      536546     22145         NaN         1 2010-12-01 14:33:00
# 1972      536547     37509         NaN         1 2010-12-01 14:33:00
# 1987      536549    85226A         NaN         1 2010-12-01 14:34:00
# ...          ...       ...         ...       ...                 ...
# 535322    581199     84581         NaN        -2 2011-12-07 18:26:00
# 535326    581203     23406         NaN        15 2011-12-07 18:31:00
# 535332    581209     21620         NaN         6 2011-12-07 18:35:00
# 536981    581234     72817         NaN        27 2011-12-08 10:33:00
# 538554    581408     85175         NaN        20 2011-12-08 14:06:00
#
#         UnitPrice  CustomerID         Country
# 622         0.000         NaN  United Kingdom
# 1970        0.000         NaN  United Kingdom
# 1971        0.000         NaN  United Kingdom
# 1972        0.000         NaN  United Kingdom
# 1987        0.000         NaN  United Kingdom
# ...           ...         ...             ...
# 535322      0.000         NaN  United Kingdom
# 535326      0.000         NaN  United Kingdom
# 535332      0.000         NaN  United Kingdom
# 536981      0.000         NaN  United Kingdom
# 538554      0.000         NaN  United Kingdom
#
# [1454 rows x 8 columns]

# %%
df[df['CustomerID'].isnull()].sample(30)
# Out:
#        InvoiceNo StockCode                          Description  Quantity  \
# 36915     539453     22835      HOT WATER BOTTLE I AM SO POORLY         5
# 264287    560090     22449             SILK PURSE BABUSHKA PINK         2
# 114115    546007     22993         SET OF 4 PANTRY JELLY MOULDS         1
# 11378     537240     90192        JADE DROP EARRINGS W FILIGREE         1
# 35705     539437     21232       STRAWBERRY CERAMIC TRINKET BOX         4
# 287804    562114     21621           VINTAGE UNION JACK BUNTING         1
# 24422     538349     21726               MULTI HEARTS  STICKERS         1
# 272758    560773     23170             REGENCY TEA PLATE ROSES          5
# 343502    566952     22386              JUMBO BAG PINK POLKADOT         1
# 240872    558117     22086      PAPER CHAIN KIT 50'S CHRISTMAS          4
# 392067    570688     22948   METAL DECORATION NAUGHTY CHILDREN          4
# 16884     537666     21790                   VINTAGE SNAP CARDS         2
# 85279     543467     22161     HEART DECORATION RUSTIC HANGING          5
# 297843    562955     22077               6 RIBBONS RUSTIC CHARM         4
# 392317    570690     22736          RIBBON REEL MAKING SNOWMEN          1
# 423160    573137     22364         GLASS JAR DIGESTIVE BISCUITS         1
# 391965    570688     21934                   SKULL SHOULDER BAG         4
# 297175    562934     22028         PENNY FARTHING BIRTHDAY CARD         1
# 57971     541219     21878  PACK OF 6 SANDCASTLE FLAGS ASSORTED         1
# 178649    552234     84923     PINK BUTTERFLY HANDBAG W BOBBLES         1
# 150988    549525    85129B     BEADED CRYSTAL HEART GREEN SMALL         2
# 60960     541423    84968E      SET OF 16 VINTAGE BLACK CUTLERY         1
# 219368    556093     21169      YOU'RE CONFUSING ME METAL SIGN          2
# 528594    580729     23373     VINTAGE CHRISTMAS PAPER GIFT BAG        16
# 310428    564184     23254        CHILDRENS CUTLERY DOLLY GIRL          4
# 268532    560433     22244           3 HOOK HANGER MAGIC GARDEN         1
# 246111    558681     22378                 WALL TIDY RETROSPOT          1
# 297728    562955     20676                   RED RETROSPOT BOWL         8
# 217541    555925     22469                HEART OF WICKER SMALL         3
# 453339    575477    84997D      CHILDRENS CUTLERY POLKADOT PINK         1
#
#                InvoiceDate  UnitPrice  CustomerID         Country
# 36915  2010-12-17 17:08:00      9.320         NaN  United Kingdom
# 264287 2011-07-14 16:46:00      2.460         NaN  United Kingdom
# 114115 2011-03-08 15:34:00      2.460         NaN  United Kingdom
# 11378  2010-12-06 10:08:00      5.090         NaN  United Kingdom
# 35705  2010-12-17 14:54:00      2.510         NaN  United Kingdom
# 287804 2011-08-02 16:14:00     16.630         NaN  United Kingdom
# 24422  2010-12-10 14:59:00      1.660         NaN  United Kingdom
# 272758 2011-07-20 16:17:00      3.290         NaN  United Kingdom
# 343502 2011-09-15 16:37:00      4.130         NaN  United Kingdom
# 240872 2011-06-27 09:11:00      6.630         NaN  United Kingdom
# 392067 2011-10-11 16:29:00      1.660         NaN  United Kingdom
# 16884  2010-12-07 18:36:00      1.660         NaN  United Kingdom
# 85279  2011-02-08 14:35:00      0.790         NaN  United Kingdom
# 297843 2011-08-11 10:14:00      4.130         NaN  United Kingdom
# 392317 2011-10-11 16:37:00      3.290         NaN  United Kingdom
# 423160 2011-10-27 17:15:00      5.790         NaN  United Kingdom
# 391965 2011-10-11 16:29:00      1.630         NaN  United Kingdom
# 297175 2011-08-10 16:56:00      0.830         NaN  United Kingdom
# 57971  2011-01-14 14:06:00      1.630         NaN  United Kingdom
# 178649 2011-05-06 16:01:00      4.130         NaN  United Kingdom
# 150988 2011-04-08 15:44:00      2.460         NaN  United Kingdom
# 60960  2011-01-17 17:54:00      8.290         NaN  United Kingdom
# 219368 2011-06-08 15:26:00      4.130         NaN  United Kingdom
# 528594 2011-12-05 17:24:00      1.630         NaN  United Kingdom
# 310428 2011-08-23 15:11:00      4.150         NaN            EIRE
# 268532 2011-07-18 15:49:00      4.130         NaN  United Kingdom
# 246111 2011-07-01 11:20:00      4.960         NaN  United Kingdom
# 297728 2011-08-11 10:14:00      2.460         NaN  United Kingdom
# 217541 2011-06-07 17:13:00      3.290         NaN  United Kingdom
# 453339 2011-11-09 16:14:00      8.290         NaN  United Kingdom

# %% [markdown]
# When we filter canceled orders by Quantity> 0 or filter non-canceled orders by Quantity <0 nothing returns, this confirms that negative values mean the order was canceled. So lets find out how many orders were cancelled?

# %% [markdown]
# #### 9288 or about 36% of the orders were cancelled. Looking deeper into why these orders were cancelled may prevent future cancellations. Now let's find out what a negative UnitPrice means.

# %%
df[df['UnitPrice']<0]
# Out:
#        InvoiceNo StockCode      Description  Quantity         InvoiceDate  \
# 299983   A563186         B  Adjust bad debt         1 2011-08-12 14:51:00
# 299984   A563187         B  Adjust bad debt         1 2011-08-12 14:52:00
#
#         UnitPrice  CustomerID         Country
# 299983 -11062.060         NaN  United Kingdom
# 299984 -11062.060         NaN  United Kingdom

# %%
df_return = df[df['Quantity']<0]

# %%
df_return.groupby('StockCode')[['Quantity','UnitPrice']].count().sort_values('UnitPrice', ascending=False)
# Out:
#            Quantity  UnitPrice
# StockCode
# M               244        244
# 22423           183        183
# POST            126        126
# 22960            87         87
# D                77         77
# ...             ...        ...
# 37503             1          1
# 21770             1          1
# 40003             1          1
# 21769             1          1
# 10002             1          1
#
# [2559 rows x 2 columns]

# %%
df[df['StockCode'] =='M'].sample(20)
# Out:
#        InvoiceNo StockCode Description  Quantity         InvoiceDate  \
# 264926    560162         M      Manual         1 2011-07-15 11:21:00
# 122282   C546859         M      Manual      -102 2011-03-17 14:39:00
# 354213    567866         M      Manual         5 2011-09-22 14:13:00
# 69745     541983         M      Manual         1 2011-01-24 15:47:00
# 270560    560575         M      Manual         1 2011-07-19 14:58:00
# 18136     537800         M      Manual        12 2010-12-08 13:08:00
# 303276   C563536         M      Manual        -1 2011-08-17 11:39:00
# 179049    552259         M      Manual         1 2011-05-08 11:13:00
# 348583    567460         M      Manual         3 2011-09-20 12:30:00
# 491733   C578073         M      Manual       -36 2011-11-22 16:02:00
# 414138    572344         M      Manual       456 2011-10-24 10:43:00
# 400626   C571327         M      Manual        -1 2011-10-17 11:12:00
# 142718    548631         M      Manual         1 2011-04-01 12:24:00
# 452218    575328         M      Manual      1200 2011-11-09 13:48:00
# 142316    548568         M      Manual         1 2011-04-01 10:43:00
# 268027   C560372         M      Manual        -1 2011-07-18 12:26:00
# 95052    C544437         M      Manual        -1 2011-02-18 17:19:00
# 134950    547873         M      Manual         1 2011-03-27 15:33:00
# 491886   C578076         M      Manual       -24 2011-11-22 16:18:00
# 148564    549245         M      Manual         2 2011-04-07 11:59:00
#
#         UnitPrice  CustomerID         Country
# 264926     10.000         NaN  United Kingdom
# 122282      5.450   17603.000  United Kingdom
# 354213      0.800   16669.000  United Kingdom
# 69745      15.000   15797.000  United Kingdom
# 270560    106.400         NaN  United Kingdom
# 18136       0.190   12748.000  United Kingdom
# 303276    413.680         NaN  United Kingdom
# 179049      1.000   15796.000  United Kingdom
# 348583      0.190   15888.000  United Kingdom
# 491733      0.560   18139.000  United Kingdom
# 414138      1.500   14607.000  United Kingdom
# 400626    283.020   12783.000        Portugal
# 142718      1.000   13184.000  United Kingdom
# 452218      0.250   17857.000  United Kingdom
# 142316     12.750   14543.000  United Kingdom
# 268027   4287.630   17448.000  United Kingdom
# 95052      82.500   16027.000  United Kingdom
# 134950     14.950   13240.000  United Kingdom
# 491886      0.560   18139.000  United Kingdom
# 148564      0.850   15005.000  United Kingdom

# %%
df[df['StockCode'] == 22423].sample(20)
#silebiliriz
# Out:
#        InvoiceNo StockCode               Description  Quantity  \
# 156908    550183     22423  REGENCY CAKESTAND 3 TIER         2
# 113904    546001     22423  REGENCY CAKESTAND 3 TIER        16
# 83827     543354     22423  REGENCY CAKESTAND 3 TIER         3
# 293063    562575     22423  REGENCY CAKESTAND 3 TIER         4
# 20988     538071     22423  REGENCY CAKESTAND 3 TIER         4
# 373905    569367     22423  REGENCY CAKESTAND 3 TIER         1
# 526390    580665     22423  REGENCY CAKESTAND 3 TIER        16
# 126492    547080     22423  REGENCY CAKESTAND 3 TIER         2
# 127252    547205     22423  REGENCY CAKESTAND 3 TIER         3
# 134699    547863     22423  REGENCY CAKESTAND 3 TIER         2
# 263030    559930     22423  REGENCY CAKESTAND 3 TIER         8
# 380271    569741     22423  REGENCY CAKESTAND 3 TIER         2
# 458938    575854     22423  REGENCY CAKESTAND 3 TIER         2
# 190727    553206     22423  REGENCY CAKESTAND 3 TIER        16
# 114428    546010     22423                   damages       -19
# 364761    568671     22423  REGENCY CAKESTAND 3 TIER         6
# 160138   C550455     22423  REGENCY CAKESTAND 3 TIER        -1
# 200009    554109     22423  REGENCY CAKESTAND 3 TIER         2
# 254185    559298     22423  REGENCY CAKESTAND 3 TIER        16
# 508911    579283     22423  REGENCY CAKESTAND 3 TIER         2
#
#                InvoiceDate  UnitPrice  CustomerID         Country
# 156908 2011-04-14 17:58:00     12.750   14105.000  United Kingdom
# 113904 2011-03-08 15:03:00     10.950   13854.000  United Kingdom
# 83827  2011-02-07 13:50:00     12.750   13458.000  United Kingdom
# 293063 2011-08-07 12:54:00     12.750   15411.000  United Kingdom
# 20988  2010-12-09 14:09:00     12.720         NaN  United Kingdom
# 373905 2011-10-03 15:28:00     12.750   13994.000  United Kingdom
# 526390 2011-12-05 14:06:00     10.950   16684.000  United Kingdom
# 126492 2011-03-20 15:06:00     12.750   15445.000  United Kingdom
# 127252 2011-03-21 14:00:00     12.750   16558.000  United Kingdom
# 134699 2011-03-27 13:07:00     12.750   12728.000          France
# 263030 2011-07-14 09:22:00     12.750   17738.000  United Kingdom
# 380271 2011-10-06 10:52:00     12.750   14626.000  United Kingdom
# 458938 2011-11-11 12:20:00     12.750   14125.000  United Kingdom
# 190727 2011-05-16 08:16:00     10.950   14156.000            EIRE
# 114428 2011-03-08 15:55:00      0.000         NaN  United Kingdom
# 364761 2011-09-28 13:13:00     10.950   13139.000  United Kingdom
# 160138 2011-04-18 13:02:00     10.950   13098.000  United Kingdom
# 200009 2011-05-22 14:33:00     12.750   12682.000          France
# 254185 2011-07-07 12:38:00     10.950   12471.000         Germany
# 508911 2011-11-29 10:45:00     12.750   13883.000  United Kingdom

# %% [markdown]
# ### iii. Handling Missing Values

# %%
df.CustomerID.isnull().count()
# Out:
# 536641

# %%
df.dropna(subset=['CustomerID'],inplace = True)
#sadece customerID sutunundaki mising value olan satirlari drop ettik.

# %%
df[df.CustomerID.isnull()==True].count()
# Out:
# InvoiceNo      0
# StockCode      0
# Description    0
# Quantity       0
# InvoiceDate    0
# UnitPrice      0
# CustomerID     0
# Country        0
# dtype: int64

# %%
df.shape
# Out:
# (401604, 8)

# %% [markdown]
# Since the customer ID's are missing, lets assume these orders were not made by the customers already in the data set because those customers already have ID's.
#
# We also don't want to assign these orders to those customers because this would alter the insights we draw from the data.

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 401604 entries, 0 to 541908
# Data columns (total 8 columns):
#  #   Column       Non-Null Count   Dtype
# ---  ------       --------------   -----
#  0   InvoiceNo    401604 non-null  object
#  1   StockCode    401604 non-null  object
#  2   Description  401604 non-null  object
#  3   Quantity     401604 non-null  int64
#  4   InvoiceDate  401604 non-null  datetime64[ns]
#  5   UnitPrice    401604 non-null  float64
#  6   CustomerID   401604 non-null  float64
#  7   Country      401604 non-null  object
# dtypes: datetime64[ns](1), float64(2), int64(1), object(4)
# memory usage: 27.6+ MB

# %% [markdown]
# ### iv. Clean the Data from the Noise and Missing Values

# %%
df[df['CustomerID']==13256]
# Out:
#        InvoiceNo StockCode                     Description  Quantity  \
# 502122    578841     84826  ASSTD DESIGN 3D PAPER STICKERS     12540
#
#                InvoiceDate  UnitPrice  CustomerID         Country
# 502122 2011-11-25 15:57:00      0.000   13256.000  United Kingdom

# %%
df.Description.isnull().sum()
# Out:
# 0

# %%
df[(df['Quantity']<0) | (df['UnitPrice']<0)][df.InvoiceNo.str.contains('C') == False]
# Out:
# Empty DataFrame
# Columns: [InvoiceNo, StockCode, Description, Quantity, InvoiceDate, UnitPrice, CustomerID, Country]
# Index: []

# %%
df
# Out:
#        InvoiceNo StockCode                          Description  Quantity  \
# 0         536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1         536365     71053                  WHITE METAL LANTERN         6
# 2         536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3         536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4         536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
# ...          ...       ...                                  ...       ...
# 541904    581587     22613          PACK OF 20 SPACEBOY NAPKINS        12
# 541905    581587     22899         CHILDREN'S APRON DOLLY GIRL          6
# 541906    581587     23254        CHILDRENS CUTLERY DOLLY GIRL          4
# 541907    581587     23255      CHILDRENS CUTLERY CIRCUS PARADE         4
# 541908    581587     22138        BAKING SET 9 PIECE RETROSPOT          3
#
#                InvoiceDate  UnitPrice  CustomerID         Country
# 0      2010-12-01 08:26:00      2.550   17850.000  United Kingdom
# 1      2010-12-01 08:26:00      3.390   17850.000  United Kingdom
# 2      2010-12-01 08:26:00      2.750   17850.000  United Kingdom
# 3      2010-12-01 08:26:00      3.390   17850.000  United Kingdom
# 4      2010-12-01 08:26:00      3.390   17850.000  United Kingdom
# ...                    ...        ...         ...             ...
# 541904 2011-12-09 12:50:00      0.850   12680.000          France
# 541905 2011-12-09 12:50:00      2.100   12680.000          France
# 541906 2011-12-09 12:50:00      4.150   12680.000          France
# 541907 2011-12-09 12:50:00      4.150   12680.000          France
# 541908 2011-12-09 12:50:00      4.950   12680.000          France
#
# [401604 rows x 8 columns]

# %%
df1=df[~df["InvoiceNo"].str.contains("C", na=False)]

# %%
df1= df[(df["Quantity"]>0)]

# %%
df1.shape
# Out:
# (392732, 8)

# %% [markdown]
# ### v. Explore the Orders

# %% [markdown]
# 1. Find the unique number of InvoiceNo  per customer

# %%
df1.groupby('CustomerID')['InvoiceNo'].nunique().sort_values(ascending=False)
#customerID=12748.000 kisi 210 defa alisveris yapmistir.
# Out:
# CustomerID
# 12748.000    210
# 14911.000    201
# 17841.000    124
# 13089.000     97
# 14606.000     93
#             ...
# 14355.000      1
# 13403.000      1
# 15488.000      1
# 14353.000      1
# 12346.000      1
# Name: InvoiceNo, Length: 4339, dtype: int64

# %% [markdown]
# 2. What's the average number of unqiue items per order or per customer?

# %%
df1.groupby('CustomerID')['StockCode'].count().mean()
# Her bir müşteri ortalama benzersiz 90 farklı ürün almıştır.
# Out:
# 90.51209956211109

# %%
df1.groupby('InvoiceNo')['StockCode'].count().mean()
# Her bir siparişte ortalama benzersiz 21 farklı ürün alınmıştır.
# Out:
# 21.187526974536038

# %%
df1.groupby(['CustomerID', 'InvoiceNo'])['StockCode'].count()
# Out:
# CustomerID  InvoiceNo
# 12346.000   541431        1
# 12347.000   537626       31
#             542237       29
#             549222       24
#             556201       18
#                          ..
# 18283.000   579673       50
#             580872       50
# 18287.000   554065       29
#             570715       38
#             573167        3
# Name: StockCode, Length: 18536, dtype: int64

# %% [markdown]
# 3. Let's see how this compares to the number of unique products per customer.

# %%
df1.groupby('CustomerID')['StockCode'].nunique().sort_values(ascending=False)
# Out:
# CustomerID
# 14911.000    1787
# 12748.000    1768
# 17841.000    1323
# 14096.000    1119
# 14298.000     884
#              ...
# 13366.000       1
# 13391.000       1
# 13452.000       1
# 16078.000       1
# 12346.000       1
# Name: StockCode, Length: 4339, dtype: int64

# %% [markdown]
# ### vi. Explore Customers by Country

# %%
df["Country"].value_counts().plot(kind="pie", autopct='%1.1f%%',figsize=(12,10));

# %% [markdown]
# 1. What's the total revenue per country?

# %%
df1['Total_Price'] =(df1.UnitPrice) * (df1.Quantity)

# %%
df1.head()
# Out:
#   InvoiceNo StockCode                          Description  Quantity  \
# 0    536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1    536365     71053                  WHITE METAL LANTERN         6
# 2    536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3    536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4    536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
#
#           InvoiceDate  UnitPrice  CustomerID         Country  Total_Price
# 0 2010-12-01 08:26:00      2.550   17850.000  United Kingdom       15.300
# 1 2010-12-01 08:26:00      3.390   17850.000  United Kingdom       20.340
# 2 2010-12-01 08:26:00      2.750   17850.000  United Kingdom       22.000
# 3 2010-12-01 08:26:00      3.390   17850.000  United Kingdom       20.340
# 4 2010-12-01 08:26:00      3.390   17850.000  United Kingdom       20.340

# %%
df1.groupby('Country')['Total_Price'].sum().sort_values(ascending = False)
# Out:
# Country
# United Kingdom         7285024.644
# Netherlands             285446.340
# EIRE                    265262.460
# Germany                 228678.400
# France                  208934.310
# Australia               138453.810
# Spain                    61558.560
# Switzerland              56443.950
# Belgium                  41196.340
# Sweden                   38367.830
# Japan                    37416.370
# Norway                   36165.440
# Portugal                 33375.840
# Finland                  22546.080
# Singapore                21279.290
# Channel Islands          20440.540
# Denmark                  18955.340
# Italy                    17483.240
# Cyprus                   13502.850
# Austria                  10198.680
# Poland                    7334.650
# Israel                    7215.840
# Greece                    4760.520
# Iceland                   4310.000
# Canada                    3666.380
# USA                       3580.390
# Malta                     2725.590
# Unspecified               2660.770
# United Arab Emirates      1902.280
# Lebanon                   1693.880
# Lithuania                 1661.060
# European Community        1300.250
# Brazil                    1143.600
# RSA                       1002.310
# Czech Republic             826.740
# Bahrain                    548.400
# Saudi Arabia               145.920
# Name: Total_Price, dtype: float64

# %% [markdown]
# 2. Visualize number of customer per country

# %%
xx =df1.groupby(['Country'])['CustomerID'].nunique().sort_values(ascending=False)
plt.figure(figsize=(12,10))
sns.barplot(xx.values,xx.index)
# Out:
# <AxesSubplot:ylabel='Country'>

# %% [markdown]
# 3. Visualize total cost per country

# %%
xx =df1.groupby(['Country'])['Total_Price'].sum().sort_values(ascending=False)
plt.figure(figsize=(12,10))
sns.barplot(xx.values,xx.index)
# Out:
# <AxesSubplot:ylabel='Country'>

# %% [markdown]
# #### The UK not only has the most sales revenue, but also the most customers. Since the majority of this data set contains orders from the UK, we can explore the UK market further by finding out what products the customers buy together and any other buying behaviors to improve our sales and targeting strategy.

# %% [markdown]
# ### vii. Explore the UK Market

# %% [markdown]
# 1. Create df_uk DataFrame

# %%
df_uk=df1[df1.Country=='United Kingdom']

# %% [markdown]
# 2. What are the most popular products that are bought in the UK?

# %%
df_uk.groupby(['StockCode','Description'])[['Quantity']].sum().sort_values(by='Quantity',ascending=False).head()
#paper craft, little birdie
# Out:
#                                               Quantity
# StockCode Description
# 23843     PAPER CRAFT , LITTLE BIRDIE            80995
# 23166     MEDIUM CERAMIC TOP STORAGE JAR         76919
# 84077     WORLD WAR 2 GLIDERS ASSTD DESIGNS      49086
# 85099B    JUMBO BAG RED RETROSPOT                41878
# 85123A    WHITE HANGING HEART T-LIGHT HOLDER     34630

# %% [markdown]
# ### We will continue analyzing the UK transactions with customer segmentation.

# %% [markdown]
# # 2. RFM Analysis

# %% [markdown]
# In the age of the internet and e-commerce, companies that do not expand their businesses online or utilize digital tools to reach their customers will run into issues like scalability and a lack of digital precsence. An important marketing strategy e-commerce businesses use for analyzing and predicting customer value is customer segmentation. Customer data is used to sort customers into group based on their behaviors and preferences.
#
# **[RFM](https://www.putler.com/rfm-analysis/) (Recency, Frequency, Monetary) Analysis** is a customer segmentation technique for analyzing customer value based on past buying behavior. RFM analysis was first used by the direct mail industry more than four decades ago, yet it is still an effective way to optimize your marketing.
# <br>
# <br>
# Our goal in this Notebook is to cluster the customers in our data set to:
#  - Recognize who are our most valuable customers
#  - Increase revenue
#  - Increase customer retention
#  - Learn more about the trends and behaviors of our customers
#  - Define customers that are at risk
#
# We will start with **RFM Analysis** and then compliment our findings with predictive analysis using **K-Means Clustering Algorithms.**
#
# - RECENCY (R): Time since last purchase
# - FREQUENCY (F): Total number of purchases
# - MONETARY VALUE (M): Total monetary value
#
#
#
#
# Benefits of RFM Analysis
#
# - Increased customer retention
# - Increased response rate
# - Increased conversion rate
# - Increased revenue
#
# RFM Analysis answers the following questions:
#  - Who are our best customers?
#  - Who has the potential to be converted into more profitable customers?
#  - Which customers do we need to retain?
#  - Which group of customers is most likely to respond to our marketing campaign?

# %% [markdown]
# ### i. Import Libraries

# %%
import datetime as dt
from datetime import timedelta

# %% [markdown]
# ### ii. Review df_uk DataFrame

# %%
df_uk.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 349227 entries, 0 to 541893
# Data columns (total 9 columns):
#  #   Column       Non-Null Count   Dtype
# ---  ------       --------------   -----
#  0   InvoiceNo    349227 non-null  object
#  1   StockCode    349227 non-null  object
#  2   Description  349227 non-null  object
#  3   Quantity     349227 non-null  int64
#  4   InvoiceDate  349227 non-null  datetime64[ns]
#  5   UnitPrice    349227 non-null  float64
#  6   CustomerID   349227 non-null  float64
#  7   Country      349227 non-null  object
#  8   Total_Price  349227 non-null  float64
# dtypes: datetime64[ns](1), float64(3), int64(1), object(4)
# memory usage: 26.6+ MB

# %%
df_uk.shape
# Out:
# (349227, 9)

# %% [markdown]
# ### iii. Recency: Days since last purchase
# To calculate the recency values, follow these steps in order:
#
# 1. To calculate recency, we need to choose a date as a point of reference to evaluate how many days ago was the customer's last purchase.
# 2. Create a new column called Date which contains the invoice date without the timestamp
# 3. Group by CustomerID and check the last date of purchase
# 4. Calculate the days since last purchase
# 5. Drop Last_Purchase_Date since we don't need it anymore
# 6. Plot RFM distributions

# %% [markdown]
# 1. Choose a date as a point of reference to evaluate how many days ago was the customer's last purchase.

# %%
df_uk.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 349227 entries, 0 to 541893
# Data columns (total 9 columns):
#  #   Column       Non-Null Count   Dtype
# ---  ------       --------------   -----
#  0   InvoiceNo    349227 non-null  object
#  1   StockCode    349227 non-null  object
#  2   Description  349227 non-null  object
#  3   Quantity     349227 non-null  int64
#  4   InvoiceDate  349227 non-null  datetime64[ns]
#  5   UnitPrice    349227 non-null  float64
#  6   CustomerID   349227 non-null  float64
#  7   Country      349227 non-null  object
#  8   Total_Price  349227 non-null  float64
# dtypes: datetime64[ns](1), float64(3), int64(1), object(4)
# memory usage: 26.6+ MB

# %%
ref_date = df_uk['InvoiceDate'].max()+timedelta(days=3)
ref_date

#hocalara sorulucak.!
# Out:
# Timestamp('2011-12-12 12:49:00')

# %%
df_rec = pd.DataFrame(df_uk.groupby('CustomerID')['InvoiceDate'].max().dt.date)
df_rec
# Out:
#            InvoiceDate
# CustomerID
# 12346.000   2011-01-18
# 12747.000   2011-12-07
# 12748.000   2011-12-09
# 12749.000   2011-12-06
# 12820.000   2011-12-06
# ...                ...
# 18280.000   2011-03-07
# 18281.000   2011-06-12
# 18282.000   2011-12-02
# 18283.000   2011-12-06
# 18287.000   2011-10-28
#
# [3921 rows x 1 columns]

# %%
df_rec['ref_date'] = ref_date
df_rec["ref_date"] = df_rec["ref_date"].dt.date
df_rec
# Out:
#            InvoiceDate    ref_date
# CustomerID
# 12346.000   2011-01-18  2011-12-12
# 12747.000   2011-12-07  2011-12-12
# 12748.000   2011-12-09  2011-12-12
# 12749.000   2011-12-06  2011-12-12
# 12820.000   2011-12-06  2011-12-12
# ...                ...         ...
# 18280.000   2011-03-07  2011-12-12
# 18281.000   2011-06-12  2011-12-12
# 18282.000   2011-12-02  2011-12-12
# 18283.000   2011-12-06  2011-12-12
# 18287.000   2011-10-28  2011-12-12
#
# [3921 rows x 2 columns]

# %%
df_rec["Last_Purchased"] = df_rec.ref_date - df_rec["InvoiceDate"]

df_rec
# Out:
#            InvoiceDate    ref_date Last_Purchased
# CustomerID
# 12346.000   2011-01-18  2011-12-12       328 days
# 12747.000   2011-12-07  2011-12-12         5 days
# 12748.000   2011-12-09  2011-12-12         3 days
# 12749.000   2011-12-06  2011-12-12         6 days
# 12820.000   2011-12-06  2011-12-12         6 days
# ...                ...         ...            ...
# 18280.000   2011-03-07  2011-12-12       280 days
# 18281.000   2011-06-12  2011-12-12       183 days
# 18282.000   2011-12-02  2011-12-12        10 days
# 18283.000   2011-12-06  2011-12-12         6 days
# 18287.000   2011-10-28  2011-12-12        45 days
#
# [3921 rows x 3 columns]

# %% [markdown]
# 2. Create a new column called Date which contains the invoice date without the timestamp

# %%
df_rec['Date']= df_rec.InvoiceDate
df_rec
# Out:
#            InvoiceDate    ref_date Last_Purchased        Date
# CustomerID
# 12346.000   2011-01-18  2011-12-12       328 days  2011-01-18
# 12747.000   2011-12-07  2011-12-12         5 days  2011-12-07
# 12748.000   2011-12-09  2011-12-12         3 days  2011-12-09
# 12749.000   2011-12-06  2011-12-12         6 days  2011-12-06
# 12820.000   2011-12-06  2011-12-12         6 days  2011-12-06
# ...                ...         ...            ...         ...
# 18280.000   2011-03-07  2011-12-12       280 days  2011-03-07
# 18281.000   2011-06-12  2011-12-12       183 days  2011-06-12
# 18282.000   2011-12-02  2011-12-12        10 days  2011-12-02
# 18283.000   2011-12-06  2011-12-12         6 days  2011-12-06
# 18287.000   2011-10-28  2011-12-12        45 days  2011-10-28
#
# [3921 rows x 4 columns]

# %%
df_uk["Date"] = df_uk.groupby('CustomerID')['InvoiceDate'].transform(max).dt.date

# %%
df_uk.isnull().any()
# Out:
# InvoiceNo      False
# StockCode      False
# Description    False
# Quantity       False
# InvoiceDate    False
# UnitPrice      False
# CustomerID     False
# Country        False
# Total_Price    False
# Date           False
# dtype: bool

# %% [markdown]
# 3. Group by CustomerID and check the last date of purchase

# %%
df_uk.groupby('CustomerID')['InvoiceDate'].max()
# Out:
# CustomerID
# 12346.000   2011-01-18 10:01:00
# 12747.000   2011-12-07 14:34:00
# 12748.000   2011-12-09 12:20:00
# 12749.000   2011-12-06 09:56:00
# 12820.000   2011-12-06 15:12:00
#                     ...
# 18280.000   2011-03-07 09:52:00
# 18281.000   2011-06-12 10:53:00
# 18282.000   2011-12-02 11:43:00
# 18283.000   2011-12-06 12:02:00
# 18287.000   2011-10-28 09:29:00
# Name: InvoiceDate, Length: 3921, dtype: datetime64[ns]

# %%
df_uk.CustomerID.nunique()
# Out:
# 3921

# %% [markdown]
# 4. Calculate the days since last purchase

# %%
df_rec["Last_Purchased"].sort_values(ascending=False)#.astype("int64")
# Out:
# CustomerID
# 17643.000   376 days
# 15165.000   376 days
# 13747.000   376 days
# 17908.000   376 days
# 17968.000   376 days
#               ...
# 17581.000     3 days
# 17364.000     3 days
# 14051.000     3 days
# 15311.000     3 days
# 13113.000     3 days
# Name: Last_Purchased, Length: 3921, dtype: timedelta64[ns]

# %% [markdown]
# 5. Drop Last_Purchase_Date since we don't need it anymore

# %%
df_rec = df_rec.drop(axis = 1,columns = ["Date","ref_date","InvoiceDate"])

# %%
df_rec
# Out:
#            Last_Purchased
# CustomerID
# 12346.000        328 days
# 12747.000          5 days
# 12748.000          3 days
# 12749.000          6 days
# 12820.000          6 days
# ...                   ...
# 18280.000        280 days
# 18281.000        183 days
# 18282.000         10 days
# 18283.000          6 days
# 18287.000         45 days
#
# [3921 rows x 1 columns]

# %%
df_rec["Recency"] = pd.to_numeric(df_rec['Last_Purchased'].dt.days.astype('int16'))

# %%
df_rec.drop(columns= "Last_Purchased", inplace = True)

# %%
df_rec = pd.DataFrame(df_rec)
df_rec
# Out:
#             Recency
# CustomerID
# 12346.000       328
# 12747.000         5
# 12748.000         3
# 12749.000         6
# 12820.000         6
# ...             ...
# 18280.000       280
# 18281.000       183
# 18282.000        10
# 18283.000         6
# 18287.000        45
#
# [3921 rows x 1 columns]

# %% [markdown]
# 6. Plot RFM distributions

# %%
plt.figure(figsize=(10,8))
sns.distplot(df_rec.Recency, kde = False)
# Out:
# <AxesSubplot:xlabel='Recency'>

# %%
plt.figure(figsize=(10,8))
sns.scatterplot(data = df_rec.Recency)
# Out:
# <AxesSubplot:xlabel='CustomerID', ylabel='Recency'>

# %% [markdown]
# ### iv. Frequency: Number of purchases
#
# To calculate how many times a customer purchased something, we need to count how many invoices each customer has. To calculate the frequency values, follow these steps in order:

# %% [markdown]
# 1. Make a copy of df_uk and drop duplicates

# %%
df_uk2 = df_uk.copy()
df_uk2
# Out:
#        InvoiceNo StockCode                          Description  Quantity  \
# 0         536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1         536365     71053                  WHITE METAL LANTERN         6
# 2         536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3         536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4         536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
# ...          ...       ...                                  ...       ...
# 541889    581585     22466       FAIRY TALE COTTAGE NIGHT LIGHT        12
# 541890    581586     22061  LARGE CAKE STAND  HANGING STRAWBERY         8
# 541891    581586     23275     SET OF 3 HANGING OWLS OLLIE BEAK        24
# 541892    581586     21217        RED RETROSPOT ROUND CAKE TINS        24
# 541893    581586     20685                DOORMAT RED RETROSPOT        10
#
#                InvoiceDate  UnitPrice  CustomerID         Country  \
# 0      2010-12-01 08:26:00      2.550   17850.000  United Kingdom
# 1      2010-12-01 08:26:00      3.390   17850.000  United Kingdom
# 2      2010-12-01 08:26:00      2.750   17850.000  United Kingdom
# 3      2010-12-01 08:26:00      3.390   17850.000  United Kingdom
# 4      2010-12-01 08:26:00      3.390   17850.000  United Kingdom
# ...                    ...        ...         ...             ...
# 541889 2011-12-09 12:31:00      1.950   15804.000  United Kingdom
# 541890 2011-12-09 12:49:00      2.950   13113.000  United Kingdom
# 541891 2011-12-09 12:49:00      1.250   13113.000  United Kingdom
# 541892 2011-12-09 12:49:00      8.950   13113.000  United Kingdom
# 541893 2011-12-09 12:49:00      7.080   13113.000  United Kingdom
#
#         Total_Price        Date
# 0            15.300  2010-12-02
# 1            20.340  2010-12-02
# 2            22.000  2010-12-02
# 3            20.340  2010-12-02
# 4            20.340  2010-12-02
# ...             ...         ...
# 541889       23.400  2011-12-09
# 541890       23.600  2011-12-09
# 541891       30.000  2011-12-09
# 541892      214.800  2011-12-09
# 541893       70.800  2011-12-09
#
# [349227 rows x 10 columns]

# %%
df_uk2.duplicated().sum()
# Out:
# 0

# %% [markdown]
# 2. Calculate the frequency of purchases

# %%
df_freq = pd.DataFrame(df_uk.groupby('CustomerID')['InvoiceNo'].nunique())

# %%
df_freq.rename(columns = {"InvoiceNo" : "Frequency"}, inplace =True)

# %%
df_freq.head()
# Out:
#             Frequency
# CustomerID
# 12346.000           1
# 12747.000          11
# 12748.000         210
# 12749.000           5
# 12820.000           4

# %% [markdown]
# 3. Plot RFM distributions

# %%
plt.figure(figsize=(10,8))
sns.scatterplot(data = df_freq.Frequency);

# %% [markdown]
# ### v. Monetary: Total amount of money spent
#
# The monetary value is calculated by adding together the cost of the customers' purchases.

# %% [markdown]
# 1. Calculate sum total cost by customers and named "Monetary"

# %%
df_money = pd.DataFrame(df_uk.groupby("CustomerID")["Total_Price"].sum())

# %%
df_money
# Out:
#             Total_Price
# CustomerID
# 12346.000     77183.600
# 12747.000      4196.010
# 12748.000     33053.190
# 12749.000      4090.880
# 12820.000       942.340
# ...                 ...
# 18280.000       180.600
# 18281.000        80.820
# 18282.000       178.050
# 18283.000      2045.530
# 18287.000      1837.280
#
# [3921 rows x 1 columns]

# %%
df_money.rename(columns = {'Total_Price':'Monetary'}, inplace = True)

# %%
df_money.head()
# Out:
#             Monetary
# CustomerID
# 12346.000  77183.600
# 12747.000   4196.010
# 12748.000  33053.190
# 12749.000   4090.880
# 12820.000    942.340

# %% [markdown]
# 2. Plot RFM distributions

# %%
plt.figure(figsize=(10,8))
sns.scatterplot(data = df_money.Monetary);

# %% [markdown]
# ### vi. Create RFM Table
# Merge the recency, frequency and motetary dataframes

# %%
df_RFM = pd.merge(df_rec, df_freq, on = "CustomerID")

# %%
df_RFM = pd.merge(df_RFM, df_money, on = "CustomerID")

# %%
df_RFM.head()
# Out:
#             Recency  Frequency  Monetary
# CustomerID
# 12346.000       328          1 77183.600
# 12747.000         5         11  4196.010
# 12748.000         3        210 33053.190
# 12749.000         6          5  4090.880
# 12820.000         6          4   942.340

# %% [markdown]
# # 3. Customer Segmentation with RFM Scores

# %% [markdown]
# Businesses have this ever-lasting urge to understand their customers. The better you understand the customer, the better you serve them, and the higher the financial gain you receive from that customer. Since the dawn of trade, this process of understanding customers for a strategic gain has been there practiced and this task is known majorly as [Customer Segmentation](https://clevertap.com/blog/rfm-analysis/).
# Well as the name suggests, Customer Segmentation could segment customers according to their precise needs. Some of the common ways of segmenting customers are based on their Recency-Frequency-Monatory values, their demographics like gender, region, country, etc, and some of their business-crafted scores. You will use Recency-Frequency-Monatory values for this case.
#
# In this section, you will create an RFM Segmentation Table where you segment your customers by using the RFM table. For example, you can label the best customer as "Big Spenders" and the lost customer as "Lost Customer".

# %% [markdown]
# ## Calculate RFM Scoring
#
# The simplest way to create customer segments from an RFM model is by using **Quartiles**. We will assign a score from 1 to 4 to each category (Recency, Frequency, and Monetary) with 4 being the highest/best value. The final RFM score is calculated by combining all RFM values. For Customer Segmentation, you will use the df_rfm data set resulting from the RFM analysis.
# <br>
# <br>
# **Note**: Data can be assigned into more groups for better granularity, but we will use 4 in this case.

# %% [markdown]
# 1. Divide the df_rfm into quarters

# %%
df_RFM.describe().T
# Out:
#              count     mean      std   min     25%     50%      75%        max
# Recency   3921.000   94.722   99.529 3.000  20.000  53.000  145.000    376.000
# Frequency 3921.000    4.246    7.206 1.000   1.000   2.000    5.000    210.000
# Monetary  3921.000 1857.951 7477.736 0.000 298.110 644.300 1570.810 259657.300

# %%
def moneteray_score(rfm):
    if rfm.Monetary <= 298.110:
        moneteray_score = 1
    elif rfm.Monetary <= 644.300:
        moneteray_score = 2
    elif rfm.Monetary <= 1570.810:
        moneteray_score = 3
    else:
        moneteray_score = 4
    return moneteray_score
df_RFM['M'] = df_RFM.apply(moneteray_score, axis=1)
df_RFM.head()
#Harcadigi para miktarina gore scorelar
# Out:
#             Recency  Frequency  Monetary  M
# CustomerID
# 12346.000       328          1 77183.600  4
# 12747.000         5         11  4196.010  4
# 12748.000         3        210 33053.190  4
# 12749.000         6          5  4090.880  4
# 12820.000         6          4   942.340  3

# %%
def frequncy_scor(rfm):
    if rfm.Frequency <= 1:
        frequncy_scor = 1
    elif rfm.Frequency <= 2:
        frequncy_scor = 2
    elif rfm.Frequency <= 5:
        frequncy_scor =3
    else:
        frequncy_scor = 4
    return frequncy_scor
df_RFM['F'] = df_RFM.apply(frequncy_scor, axis=1)
df_RFM.head()
#Alisveris yaptigi sikliga gore scorelar.
# Out:
#             Recency  Frequency  Monetary  M  F
# CustomerID
# 12346.000       328          1 77183.600  4  1
# 12747.000         5         11  4196.010  4  4
# 12748.000         3        210 33053.190  4  4
# 12749.000         6          5  4090.880  4  3
# 12820.000         6          4   942.340  3  3

# %%
def recency_scoring(rfm):
    if rfm.Recency <= 17.0:
        recency_score = 4
    elif rfm.Recency <= 50.0:
        recency_score = 3
    elif rfm.Recency <= 142.0:
        recency_score = 2
    else:
        recency_score = 1
    return recency_score
df_RFM['R'] = df_RFM.apply(recency_scoring, axis=1)
df_RFM.head()
#En son yaptigi alisveris tarihini hesaplar
# Out:
#             Recency  Frequency  Monetary  M  F  R
# CustomerID
# 12346.000       328          1 77183.600  4  1  1
# 12747.000         5         11  4196.010  4  4  4
# 12748.000         3        210 33053.190  4  4  4
# 12749.000         6          5  4090.880  4  3  4
# 12820.000         6          4   942.340  3  3  4

# %%
df_RFM.head()
# Out:
#             Recency  Frequency  Monetary  M  F  R
# CustomerID
# 12346.000       328          1 77183.600  4  1  1
# 12747.000         5         11  4196.010  4  4  4
# 12748.000         3        210 33053.190  4  4  4
# 12749.000         6          5  4090.880  4  3  4
# 12820.000         6          4   942.340  3  3  4

# %% [markdown]
# ### i. Creating the RFM Segmentation Table

# %% [markdown]
# 1. Create two functions, one for Recency and one for Frequency and Monetary. For Recency, customers in the first quarter should be scored as 4, this represents the highest Recency value. Conversely, for Frequency and Monetary, customers in the last quarter should be scored as 4, representing the highest Frequency and Monetary values.

# %%
df_RFM.head()
# Out:
#             Recency  Frequency  Monetary  M  F  R
# CustomerID
# 12346.000       328          1 77183.600  4  1  1
# 12747.000         5         11  4196.010  4  4  4
# 12748.000         3        210 33053.190  4  4  4
# 12749.000         6          5  4090.880  4  3  4
# 12820.000         6          4   942.340  3  3  4

# %% [markdown]
# 2. Score customers from 1 to 4 by applying the functions you have created. Also create separate score column for each value.

# %%
def weighted_rfm(y): # Recency için 2,  Frequency için 3 , Monetary için 5. seklinde agirlik verdik.
    return y.R*2 + y.F*3 + y.M*5
df_RFM["WeightedRFM_score"] = df_RFM.apply(weighted_rfm,axis=1)

# %%
def rfm_score(x):
    return str(x.R) + str(x.F) + str(x.M)
df_RFM["RFM_LABEL"] = df_RFM.apply(rfm_score,axis=1)

# %% [markdown]
# 3. Now that scored each customer, you'll combine the scores for segmentation.

# %%
df_RFM.head()
# Out:
#             Recency  Frequency  Monetary  M  F  R  WeightedRFM_score RFM_LABEL
# CustomerID
# 12346.000       328          1 77183.600  4  1  1                 25       114
# 12747.000         5         11  4196.010  4  4  4                 40       444
# 12748.000         3        210 33053.190  4  4  4                 40       444
# 12749.000         6          5  4090.880  4  3  4                 37       434
# 12820.000         6          4   942.340  3  3  4                 32       433

# %% [markdown]
# 4. Define rfm_level function that tags customers by using RFM_Scrores and Create a new variable RFM_Level

# %%
def cathegorizer(x):
    if x.WeightedRFM_score >35:
        x = 'Loyal Customers'
        
    elif x.WeightedRFM_score >30:
        x = 'Potential Loyalist'
        
    elif x.WeightedRFM_score >25:
        x = 'Good Customers'
    
    elif  x.WeightedRFM_score >20:
        x = 'Customers Needing Attention'
    
    elif  x.WeightedRFM_score >15:
        x = 'Try to Get Them Back'
    
    elif  x.WeightedRFM_score >=10:
        x = 'Losted Customer'
 
    return x 
df_RFM["RFM_Level"] = df_RFM.apply(cathegorizer,axis=1)
df_RFM
# Out:
#             Recency  Frequency  Monetary  M  F  R  WeightedRFM_score  \
# CustomerID
# 12346.000       328          1 77183.600  4  1  1                 25
# 12747.000         5         11  4196.010  4  4  4                 40
# 12748.000         3        210 33053.190  4  4  4                 40
# 12749.000         6          5  4090.880  4  3  4                 37
# 12820.000         6          4   942.340  3  3  4                 32
# ...             ...        ...       ... .. .. ..                ...
# 18280.000       280          1   180.600  1  1  1                 10
# 18281.000       183          1    80.820  1  1  1                 10
# 18282.000        10          2   178.050  1  2  4                 19
# 18283.000         6         16  2045.530  4  4  4                 40
# 18287.000        45          3  1837.280  4  3  3                 35
#
#            RFM_LABEL                    RFM_Level
# CustomerID
# 12346.000        114  Customers Needing Attention
# 12747.000        444              Loyal Customers
# 12748.000        444              Loyal Customers
# 12749.000        434              Loyal Customers
# 12820.000        433           Potential Loyalist
# ...              ...                          ...
# 18280.000        111              Losted Customer
# 18281.000        111              Losted Customer
# 18282.000        421         Try to Get Them Back
# 18283.000        444              Loyal Customers
# 18287.000        334           Potential Loyalist
#
# [3921 rows x 9 columns]

# %%
plt.figure(figsize=(12,8))
ax = sns.displot(df_RFM.RFM_Level,kde=False)
ax.set_xticklabels(rotation = 30)

# %% [markdown]
# 5. Calculate average values for each RFM_Level, and return a size of each segment

# %%
df_RFM.RFM_Level.value_counts()
# Out:
# Losted Customer                1043
# Loyal Customers                 721
# Good Customers                  581
# Try to Get Them Back            579
# Customers Needing Attention     539
# Potential Loyalist              458
# Name: RFM_Level, dtype: int64

# %% [markdown]
# ## Plot RFM Segments

# %% [markdown]
# 1. Create your plot and resize it.

# %%
RFM_segments= pd.DataFrame(df_RFM.RFM_Level.value_counts(dropna=False).sort_values(ascending=False))
RFM_segments.reset_index(inplace=True)
RFM_segments.rename(columns={'index':'RFM_segments', 'RFM_Level':'Customers'}, inplace=True)
RFM_segments
# Out:
#                   RFM_segments  Customers
# 0              Losted Customer       1043
# 1              Loyal Customers        721
# 2               Good Customers        581
# 3         Try to Get Them Back        579
# 4  Customers Needing Attention        539
# 5           Potential Loyalist        458

# %%
plt.figure(figsize=(19, 8))
sns.barplot(data=RFM_segments, x='RFM_segments', y='Customers', palette='Oranges_r')
# Out:
# <AxesSubplot:xlabel='RFM_segments', ylabel='Customers'>

# %% [markdown]
# Using customer segmentation categories found [here](http://www.blastam.com/blog/rfm-analysis-boosts-sales) we can formulate different marketing strategies and approaches for customer engagement for each type of customer.
#
# Note: The author in the article scores 1 as the highest and 4 as the lowest

# %% [markdown]
# 2. How many customers do we have in each segment?

# %%
df_RFM.RFM_Level.value_counts()
# Out:
# Losted Customer                1043
# Loyal Customers                 721
# Good Customers                  581
# Try to Get Them Back            579
# Customers Needing Attention     539
# Potential Loyalist              458
# Name: RFM_Level, dtype: int64

# %% [markdown]
# # 3. Applying K-Means Clustering

# %% [markdown]
# Now that we have our customers segmented into 6 different categories, we can gain further insight into customer behavior by using predictive models in conjuction with out RFM model.
# Possible algorithms include **Logistic Regression**, **K-means Clustering**, and **K-nearest Neighbor**. We will go with [K-Means](https://towardsdatascience.com/understanding-k-means-clustering-in-machine-learning-6a6e67336aa1) since we already have our distinct groups determined. K-means has also been widely used for market segmentation and has the advantage of being simple to implement.

# %% [markdown]
# ## Data Pre-Processing and Exploring

# %%
df_RFM
# Out:
#             Recency  Frequency  Monetary  M  F  R  WeightedRFM_score  \
# CustomerID
# 12346.000       328          1 77183.600  4  1  1                 25
# 12747.000         5         11  4196.010  4  4  4                 40
# 12748.000         3        210 33053.190  4  4  4                 40
# 12749.000         6          5  4090.880  4  3  4                 37
# 12820.000         6          4   942.340  3  3  4                 32
# ...             ...        ...       ... .. .. ..                ...
# 18280.000       280          1   180.600  1  1  1                 10
# 18281.000       183          1    80.820  1  1  1                 10
# 18282.000        10          2   178.050  1  2  4                 19
# 18283.000         6         16  2045.530  4  4  4                 40
# 18287.000        45          3  1837.280  4  3  3                 35
#
#            RFM_LABEL                    RFM_Level
# CustomerID
# 12346.000        114  Customers Needing Attention
# 12747.000        444              Loyal Customers
# 12748.000        444              Loyal Customers
# 12749.000        434              Loyal Customers
# 12820.000        433           Potential Loyalist
# ...              ...                          ...
# 18280.000        111              Losted Customer
# 18281.000        111              Losted Customer
# 18282.000        421         Try to Get Them Back
# 18283.000        444              Loyal Customers
# 18287.000        334           Potential Loyalist
#
# [3921 rows x 9 columns]

# %%
df_kmeans = df_RFM[['Recency','Frequency','Monetary']]
df_kmeans
# Out:
#             Recency  Frequency  Monetary
# CustomerID
# 12346.000       328          1 77183.600
# 12747.000         5         11  4196.010
# 12748.000         3        210 33053.190
# 12749.000         6          5  4090.880
# 12820.000         6          4   942.340
# ...             ...        ...       ...
# 18280.000       280          1   180.600
# 18281.000       183          1    80.820
# 18282.000        10          2   178.050
# 18283.000         6         16  2045.530
# 18287.000        45          3  1837.280
#
# [3921 rows x 3 columns]

# %% [markdown]
# ### i. Define and Plot Feature Correlations

# %% [markdown]
# Create Heatmap and evaluate the results

# %%
sns.heatmap(df_kmeans.corr(), annot = True)
# Out:
# <AxesSubplot:>

# %% [markdown]
# ### ii. Visualize Feature Distributions
#
# To get a better understanding of the dataset, you can costruct a scatter matrix of each of the three features in the RFM data.

# %%
sns.pairplot(df_kmeans)

# %% [markdown]
# ### iii. Data Normalization

# %% [markdown]
# 1. You can use the logarithm method to normalize the values in a column.

# %%
df_kmeans_norm = df_kmeans

# %%
df_kmeans_norm['Recency'] = (df_kmeans_norm.Recency).apply(np.log)
df_kmeans_norm['Frequency'] = (df_kmeans_norm.Frequency).apply(np.log)
df_kmeans_norm['Monetary'] =( df_kmeans_norm.Monetary+1.0).apply(np.log)
df_kmeans_norm.sample(10)
# Out:
#             Recency  Frequency  Monetary
# CustomerID
# 12990.000     3.526      1.099     6.017
# 16368.000     1.609      0.693     6.176
# 14628.000     4.543      0.693     6.512
# 16913.000     5.680      0.000     4.740
# 14362.000     3.219      0.000     5.027
# 13083.000     1.946      0.693     5.719
# 18062.000     5.170      1.099     6.581
# 13168.000     3.664      1.386     7.171
# 17348.000     2.833      1.609     7.054
# 14443.000     4.025      1.386     7.259

# %%
#df_kmeans_norm[~np.isfinite(df_kmeans['Monetary'])]
# Out:
# Empty DataFrame
# Columns: [Recency, Frequency, Monetary]
# Index: []

# %% [markdown]
# 2. Plot normalized data with scatter matrix or pairplot. Also evaluate results.

# %%
sns.pairplot(df_kmeans_norm)
#sns.pairplot(x.drop("CustomerID", axis=1))

# %% [markdown]
# ## K-Means Implementation
#
# For k-means, you have to set k to the number of clusters you want, but figuring out how many clusters is not obvious from the beginning. We will try different cluster numbers and check their [silhouette coefficient](http://scikit-learn.org/stable/auto_examples/cluster/plot_kmeans_silhouette_analysis.html). The silhouette coefficient for a data point measures how similar it is to its assigned cluster from -1 (dissimilar) to 1 (similar).
# <br>
# <br>
# **Note**: K-means is sensitive to initializations because they are critical to qualifty of optima found. Thus, we will use smart initialization called "Elbow Method".

# %% [markdown]
# ### i. Define the Optimal Number of Clusters

# %% [markdown]
# [The Elbow Method](https://en.wikipedia.org/wiki/Elbow_method_(clustering)

# %%
from sklearn.cluster import KMeans
from sklearn.metrics import adjusted_rand_score
from yellowbrick.cluster import KElbowVisualizer
from sklearn.metrics import silhouette_samples, silhouette_score

# %%
#Normalize the variables with StandardScaler
from sklearn.preprocessing import StandardScaler
#scaler = StandardScaler()
#scaler.fit(df_kmeans)
#Store it separately for clustering
#rfm_normalized= scaler.transform(df_kmeans)

# %%
plt.rcParams['figure.facecolor'] = 'white'
model = KMeans()
visualizer = KElbowVisualizer(model, k=(4,12))

visualizer.fit(df_kmeans_norm)        # Fit the data to the visualizer
visualizer.show()
# Out:
# <AxesSubplot:title={'center':'Distortion Score Elbow for KMeans Clustering'}, xlabel='k', ylabel='distortion score'>

# %% [markdown]
# [Silhouette Coefficient](http://scikit-learn.org/stable/auto_examples/cluster/plot_kmeans_silhouette_analysis.html)

# %%
import matplotlib.cm as cm

# %%
for num_clusters in range(2,11):
    # intialise kmeans
    kmeans = KMeans(n_clusters=num_clusters, random_state=42)
    kmeans.fit(df_kmeans_norm)
    cluster_labels = kmeans.labels_
    # silhouette score
    silhouette_avg = silhouette_score(df_kmeans_norm, cluster_labels)
    print(f"For n_clusters={num_clusters}, the silhouette score is {silhouette_avg}")
# Out:
# For n_clusters=2, the silhouette score is 0.42116583797243207
# For n_clusters=3, the silhouette score is 0.325179546407589
# For n_clusters=4, the silhouette score is 0.34433994247157407
# For n_clusters=5, the silhouette score is 0.32608153725341066
# For n_clusters=6, the silhouette score is 0.3156225511582868
# For n_clusters=7, the silhouette score is 0.3100833757240927
# For n_clusters=8, the silhouette score is 0.31118471807797565
# For n_clusters=9, the silhouette score is 0.29402215766463524
# For n_clusters=10, the silhouette score is 0.2893541087178447

# %%
from sklearn.cluster import KMeans

from yellowbrick.cluster import SilhouetteVisualizer

model3 = KMeans(n_clusters=6, random_state=42)
visualizer = SilhouetteVisualizer(model3)

visualizer.fit(df_kmeans_norm)    # Fit the data to the visualizer
visualizer.poof();

# %% [markdown]
# ### ii. Model Fitting

# %% [markdown]
# Fit the K-Means Algorithm with the optimal number of clusters you decided and save the model to disk.

# %%
kmeans = KMeans(n_clusters = 6).fit(df_kmeans_norm)
labels = kmeans.labels_
df_kmeans_norm['labels'] = kmeans.labels_

# %%
df_kmeans_norm
# Out:
#             Recency  Frequency  Monetary  labels
# CustomerID
# 12346.000     5.793      0.000    11.254       3
# 12747.000     1.609      2.398     8.342       5
# 12748.000     1.099      5.347    10.406       5
# 12749.000     1.792      1.609     8.317       5
# 12820.000     1.792      1.386     6.849       0
# ...             ...        ...       ...     ...
# 18280.000     5.635      0.000     5.202       1
# 18281.000     5.209      0.000     4.405       1
# 18282.000     2.303      0.693     5.188       4
# 18283.000     1.792      2.773     7.624       5
# 18287.000     3.807      1.099     7.517       3
#
# [3921 rows x 4 columns]

# %% [markdown]
# ### iii. Visualize the Clusters

# %% [markdown]
# 1. Create a scatter plot and select cluster centers

# %%
plt.scatter(df_kmeans_norm.Recency, df_kmeans_norm.Frequency, c = labels, s = 50, cmap = "viridis")
plt.scatter(kmeans.cluster_centers_[:, 0], kmeans.cluster_centers_[:,1], s=200, c='red',alpha=0.5, label = 'Centroids')
#Her bir clusterin merkez noktalarini aldik.

# %% [markdown]
# 2. Visualize Cluster Id vs Recency, Cluster Id vs Frequency and Cluster Id vs Monetary using Box plot. Also evaluate the results.

# %%
sns.boxplot(x='labels', y='Recency', data=df_kmeans_norm)
# Out:
# <AxesSubplot:xlabel='labels', ylabel='Recency'>

# %%
sns.boxplot(x='labels', y='Frequency', data=df_kmeans_norm)
# Out:
# <AxesSubplot:xlabel='labels', ylabel='Frequency'>

# %%
sns.boxplot(x='labels', y='Monetary', data=df_kmeans_norm)
# Out:
# <AxesSubplot:xlabel='labels', ylabel='Monetary'>

# %% [markdown]
# ### iv. Assign the Label

# %%
df_kmeans_norm.reset_index(inplace = True)

# %%
df_kmeans_norm['labels'].value_counts(normalize = True)
# Out:
# 1   0.214
# 2   0.203
# 4   0.177
# 0   0.161
# 3   0.146
# 5   0.099
# Name: labels, dtype: float64

# %%
df_RFM.reset_index(inplace = True)

# %%
df_RFM['Kmeans_Label'] = df_kmeans_norm['labels']

# %%
df_RFM.sample(20)
# Out:
#       CustomerID  Recency  Frequency  Monetary  M  F  R  WeightedRFM_score  \
# 1588   15070.000      375          1   106.200  1  1  1                 10
# 3733   18032.000      337          1    73.500  1  1  1                 10
# 2976   16959.000       90          1   117.350  1  1  2                 12
# 2997   16989.000       10          6  1133.250  3  4  4                 35
# 725    13849.000       54          2  1537.950  3  2  2                 25
# 57     12893.000       33          1   176.550  1  1  3                 14
# 2364   16124.000      320          1   249.000  1  1  1                 10
# 3891   18242.000       75          4  2232.490  4  3  2                 33
# 446    13437.000       17          7  3408.060  4  4  4                 40
# 70     12916.000      141          4  2944.950  4  3  2                 33
# 1110   14396.000       68          2   487.990  2  2  2                 20
# 73     12920.000       20          1   162.780  1  1  3                 14
# 2317   16059.000       68          6  1453.160  3  4  2                 31
# 3130   17186.000       49          2   144.000  1  2  3                 17
# 304    13242.000      115          3   270.400  1  3  2                 18
# 118    12985.000        3          2  1239.380  3  2  4                 29
# 654    13737.000      203          1   339.600  2  1  1                 15
# 1543   15018.000       41          3   496.210  2  3  3                 25
# 3069   17091.000        5          9  3827.760  4  4  4                 40
# 1653   15152.000       12         13  4745.690  4  4  4                 40
#
#      RFM_LABEL                    RFM_Level  Kmeans_Label
# 1588       111              Losted Customer             1
# 3733       111              Losted Customer             1
# 2976       211              Losted Customer             1
# 2997       443           Potential Loyalist             0
# 725        223  Customers Needing Attention             2
# 57         311              Losted Customer             4
# 2364       111              Losted Customer             1
# 3891       234           Potential Loyalist             3
# 446        444              Loyal Customers             3
# 70         234           Potential Loyalist             3
# 1110       222         Try to Get Them Back             2
# 73         311              Losted Customer             4
# 2317       243           Potential Loyalist             3
# 3130       321         Try to Get Them Back             4
# 304        231         Try to Get Them Back             2
# 118        423               Good Customers             0
# 654        112              Losted Customer             1
# 1543       332  Customers Needing Attention             2
# 3069       444              Loyal Customers             5
# 1653       444              Loyal Customers             5

# %%
df_RFM.groupby(['RFM_Level','Kmeans_Label'])['RFM_LABEL'].count()
# Out:
# RFM_Level                    Kmeans_Label
# Customers Needing Attention  0               109
#                              1                 3
#                              2               313
#                              3                 1
#                              4               113
# Good Customers               0               223
#                              2               258
#                              3                99
#                              4                 1
# Losted Customer              1               751
#                              2                 7
#                              4               285
# Loyal Customers              0               100
#                              3               235
#                              5               386
# Potential Loyalist           0               185
#                              2                33
#                              3               237
#                              5                 3
# Try to Get Them Back         0                14
#                              1                84
#                              2               185
#                              4               296
# Name: RFM_LABEL, dtype: int64

# %%
df_RFM.groupby(['Kmeans_Label','RFM_Level'])['RFM_LABEL'].count()
# Out:
# Kmeans_Label  RFM_Level
# 0             Customers Needing Attention    109
#               Good Customers                 223
#               Loyal Customers                100
#               Potential Loyalist             185
#               Try to Get Them Back            14
# 1             Customers Needing Attention      3
#               Losted Customer                751
#               Try to Get Them Back            84
# 2             Customers Needing Attention    313
#               Good Customers                 258
#               Losted Customer                  7
#               Potential Loyalist              33
#               Try to Get Them Back           185
# 3             Customers Needing Attention      1
#               Good Customers                  99
#               Loyal Customers                235
#               Potential Loyalist             237
# 4             Customers Needing Attention    113
#               Good Customers                   1
#               Losted Customer                285
#               Try to Get Them Back           296
# 5             Loyal Customers                386
#               Potential Loyalist               3
# Name: RFM_LABEL, dtype: int64

# %% [markdown]
# **Conclusion**
#
# - Cluster 0 : The first cluster belongs to the "Best Customers" segment which we saw earlier as they purchase recently (R=4), frequent buyers (F=4), and spent the most (M=4)
#
# - Cluster 1 : Second cluster can be interpreted as passer customers as their last purchase is long ago (R<=1),purchased very few (F>=2 & F < 4) and spent little (M>=4 & M < 4).Company has to come up with new strategies to make them permanent members. Low value customers
# - Cluster 2 : The third cluster is more related to the "Almost Lost" segment as they Haven’t purchased for some time(R=1), but used to purchase frequently and spent a lot.

# %% [markdown]
# ## cluster0 : Good Customer olarak adlandirilmistir.
# ## cluster1 : Losted Customer olarak adlandirilmistir
# ## cluster2 : Customers Needing Attention olarak adlandirilmistir.
# ## cluster3 : Potential Loyalist olarak adlandirilmistir.
# ## cluster4 : Try to Get Them Back olarak adlandirilmistir.
# ## cluster5 : Loyal Customers olarak adlandirilmistir.

# %% [markdown]
# ### v. Conclusion
#
# Discuss your final results. Compare your own labels from the Customer Segmentation with the labels found by K-Means.

# %% [markdown]
# How we want to continue this analysis depends on how the business plans to use the results and the level of granularity the business stakeholders want to see in the clusters. We can also ask what range of customer behavior from high to low value customers are the stakeholders interested in exploring. From those answers, various methods of clustering can be used and applied on RFM variable or directly on the transaction data set.

# %% [markdown]
# **Annotation:**
#
# Limitations of K-means clustering:
#
# 1. There is no assurance that it will lead to the global best solution.
# 2. Can't deal with different shapes(not circular) and consider one point's probability of belonging to more than one cluster.
#
# These disadvantages of K-means show that for many datasets (especially low-dimensional datasets), it may not perform as well as you might hope.

# %% [markdown]
# # 5. Create Cohort & Conduct Cohort Analysis
# [Cohort Analysis](https://medium.com/swlh/cohort-analysis-using-python-and-pandas-d2a60f4d0a4d) is specifically useful in analyzing user growth patterns for products. In terms of a product, a cohort can be a group of people with the same sign-up date, the same usage starts month/date, or the same traffic source.
# Cohort analysis is an analytics method by which these groups can be tracked over time for finding key insights. This analysis can further be used to do customer segmentation and track metrics like retention, churn, and lifetime value.
#
# For e-commerce organizations, cohort analysis is a unique opportunity to find out which clients are the most valuable to their business. by performing Cohort analysis you can get the following answers to the following questions:
#
# - How much effective was a marketing campaign held in a particular time period?
# - Did the strategy employ to improve the conversion rates of Customers worked?
# - Should I focus more on retention rather than acquiring new customers?
# - Are my customer nurturing strategies effective?
# - Which marketing channels bring me the best results?
# - Is there a seasonality pattern in Customer behavior?
# - Along with various performance measures/metrics for your organization.

# %% [markdown]
# Since we will be performing Cohort Analysis based on transaction records of customers, the columns we will be dealing with mainly:
# - Invoice Data
# - CustomerID
# - Price
# - Quantity
#
# The following steps will performed to generate the Cohort Chart of Retention Rate:
# - Month Extraction from InvioceDate column
# - Assigning Cohort to Each Transaction
# - Assigning Cohort Index to each transaction
# - Calculating number of unique customers in each Group of (ChortDate,Index)
# - Creating Cohort Table for Retention Rate
# - Creating the Cohort Chart using the Cohort Table
#
# The Detailed information about each step is given below:

# %% [markdown]
# ## Future Engineering

# %% [markdown]
# ### i. Extract the Month of the Purchase
# First we will create a function, which takes any date and returns the formatted date with day value as 1st of the same month and Year.

# %%
df_cohort = df_uk[['InvoiceDate','CustomerID','UnitPrice','Quantity']]

# %%
df_cohort.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 349227 entries, 0 to 541893
# Data columns (total 4 columns):
#  #   Column       Non-Null Count   Dtype
# ---  ------       --------------   -----
#  0   InvoiceDate  349227 non-null  datetime64[ns]
#  1   CustomerID   349227 non-null  float64
#  2   UnitPrice    349227 non-null  float64
#  3   Quantity     349227 non-null  int64
# dtypes: datetime64[ns](1), float64(2), int64(1)
# memory usage: 21.4 MB

# %%
df_cohort.head()
# Out:
#           InvoiceDate  CustomerID  UnitPrice  Quantity
# 0 2010-12-01 08:26:00   17850.000      2.550         6
# 1 2010-12-01 08:26:00   17850.000      3.390         6
# 2 2010-12-01 08:26:00   17850.000      2.750         8
# 3 2010-12-01 08:26:00   17850.000      3.390         6
# 4 2010-12-01 08:26:00   17850.000      3.390         6

# %%
def first_of_month(date_x):    
    dt_formatted = dt.datetime.strptime(str(date_x), '%Y-%m-%d %H:%M:%S')
    return dt.datetime(dt_formatted.year, dt_formatted.month, 1)

# %%
df_cohort['InvoiceMonth'] = df_cohort['InvoiceDate'].apply(first_of_month)
df_cohort['CohortMonth'] = df_cohort.groupby('CustomerID')['InvoiceMonth'].transform('min')
#invoicemonth ile  musterinin ilk alisveris ayini verir.

# %%
df_cohort[['InvoiceDate','InvoiceMonth', 'CohortMonth']].sample(20)
# Out:
#                InvoiceDate InvoiceMonth CohortMonth
# 306089 2011-08-18 18:11:00   2011-08-01  2011-03-01
# 236614 2011-06-22 14:21:00   2011-06-01  2010-12-01
# 534847 2011-12-07 15:07:00   2011-12-01  2010-12-01
# 510523 2011-11-29 14:38:00   2011-11-01  2011-01-01
# 487779 2011-11-21 16:10:00   2011-11-01  2011-01-01
# 310060 2011-08-23 13:35:00   2011-08-01  2011-01-01
# 495313 2011-11-23 15:14:00   2011-11-01  2011-02-01
# 371960 2011-10-02 14:56:00   2011-10-01  2011-01-01
# 384660 2011-10-07 14:05:00   2011-10-01  2010-12-01
# 305522 2011-08-18 13:44:00   2011-08-01  2011-05-01
# 432645 2011-11-01 13:20:00   2011-11-01  2010-12-01
# 94757  2011-02-18 13:32:00   2011-02-01  2010-12-01
# 93257  2011-02-17 12:29:00   2011-02-01  2011-02-01
# 236011 2011-06-22 10:11:00   2011-06-01  2011-06-01
# 67623  2011-01-23 12:07:00   2011-01-01  2011-01-01
# 181203 2011-05-09 14:10:00   2011-05-01  2011-04-01
# 130663 2011-03-23 12:24:00   2011-03-01  2010-12-01
# 518917 2011-12-01 17:56:00   2011-12-01  2010-12-01
# 137086 2011-03-29 11:25:00   2011-03-01  2011-03-01
# 399228 2011-10-16 12:25:00   2011-10-01  2011-10-01

# %% [markdown]
# Now we will use the function created above to convert all the invoice dates into respective month date format.

# %%
df_cohort.head()
# Out:
#           InvoiceDate  CustomerID  UnitPrice  Quantity InvoiceMonth  \
# 0 2010-12-01 08:26:00   17850.000      2.550         6   2010-12-01
# 1 2010-12-01 08:26:00   17850.000      3.390         6   2010-12-01
# 2 2010-12-01 08:26:00   17850.000      2.750         8   2010-12-01
# 3 2010-12-01 08:26:00   17850.000      3.390         6   2010-12-01
# 4 2010-12-01 08:26:00   17850.000      3.390         6   2010-12-01
#
#   CohortMonth
# 0  2010-12-01
# 1  2010-12-01
# 2  2010-12-01
# 3  2010-12-01
# 4  2010-12-01

# %% [markdown]
# ### ii. Calculating time offset in Months i.e. Cohort Index:
# Calculating time offset for each transaction will allows us to report the metrics for each cohort in a comparable fashion.
# First, you will create 4 variables that capture the integer value of years, months for Invoice and Cohort Date using the get_date_int() function which you'll create it below.

# %%
df_cohort['Cohort_Year'] = df_cohort['CohortMonth'].dt.year
df_cohort['Cohort_Month'] = df_cohort['CohortMonth'].dt.month
df_cohort['Invoice_Year'] = df_cohort['InvoiceMonth'].dt.year
df_cohort['Invoice_Month'] = df_cohort['InvoiceMonth'].dt.month

# %%
df_cohort.sample(20)
# Out:
#                InvoiceDate  CustomerID  UnitPrice  Quantity InvoiceMonth  \
# 519174 2011-12-01 19:42:00   17841.000      1.250        12   2011-12-01
# 401991 2011-10-17 14:01:00   12963.000      0.390        24   2011-10-01
# 275031 2011-07-22 10:00:00   14852.000      2.950         5   2011-07-01
# 386193 2011-10-09 13:30:00   15756.000      1.250         1   2011-10-01
# 99050  2011-02-23 09:14:00   17499.000      9.950         4   2011-02-01
# 12733  2010-12-06 14:05:00   15356.000      3.750         1   2010-12-01
# 158651 2011-04-17 10:27:00   14092.000      1.950        12   2011-04-01
# 464736 2011-11-14 11:09:00   13694.000      1.750       200   2011-11-01
# 320082 2011-08-31 14:35:00   17777.000      0.420         2   2011-08-01
# 523754 2011-12-04 14:55:00   13521.000      5.950         1   2011-12-01
# 97474  2011-02-22 11:02:00   17994.000      2.950         2   2011-02-01
# 8237   2010-12-05 12:26:00   15716.000      0.420         2   2010-12-01
# 258166 2011-07-11 10:12:00   14258.000      0.360       256   2011-07-01
# 12687  2010-12-06 13:58:00   17068.000      1.650         5   2010-12-01
# 300689 2011-08-14 12:27:00   16466.000      6.950         1   2011-08-01
# 443934 2011-11-06 14:29:00   15427.000      1.250         3   2011-11-01
# 92123  2011-02-16 14:27:00   13001.000      0.420        12   2011-02-01
# 215090 2011-06-06 13:31:00   18016.000      1.650         2   2011-06-01
# 985    2010-12-01 12:43:00   14729.000      2.100         1   2010-12-01
# 517782 2011-12-01 14:38:00   13969.000      3.750         4   2011-12-01
#
#        CohortMonth  Cohort_Year  Cohort_Month  Invoice_Year  Invoice_Month
# 519174  2010-12-01         2010            12          2011             12
# 401991  2010-12-01         2010            12          2011             10
# 275031  2011-04-01         2011             4          2011              7
# 386193  2011-04-01         2011             4          2011             10
# 99050   2011-02-01         2011             2          2011              2
# 12733   2010-12-01         2010            12          2010             12
# 158651  2010-12-01         2010            12          2011              4
# 464736  2010-12-01         2010            12          2011             11
# 320082  2011-08-01         2011             8          2011              8
# 523754  2011-11-01         2011            11          2011             12
# 97474   2011-02-01         2011             2          2011              2
# 8237    2010-12-01         2010            12          2010             12
# 258166  2011-01-01         2011             1          2011              7
# 12687   2010-12-01         2010            12          2010             12
# 300689  2011-02-01         2011             2          2011              8
# 443934  2011-10-01         2011            10          2011             11
# 92123   2011-01-01         2011             1          2011              2
# 215090  2010-12-01         2010            12          2011              6
# 985     2010-12-01         2010            12          2010             12
# 517782  2010-12-01         2010            12          2011             12

# %% [markdown]
# You will use this function to extract the integer values for Invoice as well as Cohort Date in 3 seperate series for each of the two columns

# %%
df_cohort.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 349227 entries, 0 to 541893
# Data columns (total 10 columns):
#  #   Column         Non-Null Count   Dtype
# ---  ------         --------------   -----
#  0   InvoiceDate    349227 non-null  datetime64[ns]
#  1   CustomerID     349227 non-null  float64
#  2   UnitPrice      349227 non-null  float64
#  3   Quantity       349227 non-null  int64
#  4   InvoiceMonth   349227 non-null  datetime64[ns]
#  5   CohortMonth    349227 non-null  datetime64[ns]
#  6   Cohort_Year    349227 non-null  int64
#  7   Cohort_Month   349227 non-null  int64
#  8   Invoice_Year   349227 non-null  int64
#  9   Invoice_Month  349227 non-null  int64
# dtypes: datetime64[ns](3), float64(2), int64(5)
# memory usage: 37.4 MB

# %% [markdown]
# Use the variables created above to calcualte the difference in days and store them in cohort Index column.

# %%
df_cohort['index'] = (df_cohort.Invoice_Year - df_cohort.Cohort_Year)*12 +( df_cohort.Invoice_Month - df_cohort.Cohort_Month)*1 + 1
#indexi gun olarak yazdirdik.

# %%
df_cohort.sample(10)
# Out:
#                InvoiceDate  CustomerID  UnitPrice  Quantity InvoiceMonth  \
# 458811 2011-11-11 12:13:00   14662.000      0.420        25   2011-11-01
# 311356 2011-08-24 10:45:00   14796.000      0.390        12   2011-08-01
# 320837 2011-09-01 11:22:00   16880.000      1.450         5   2011-09-01
# 345315 2011-09-18 10:46:00   15947.000      2.950        12   2011-09-01
# 449517 2011-11-08 14:44:00   18177.000      0.850        10   2011-11-01
# 326435 2011-09-05 12:00:00   14159.000      0.390        12   2011-09-01
# 468435 2011-11-15 11:37:00   17974.000      1.250         2   2011-11-01
# 122258 2011-03-17 14:12:00   15433.000      0.850        12   2011-03-01
# 374883 2011-10-04 09:12:00   15694.000      7.650         8   2011-10-01
# 216705 2011-06-07 13:37:00   13050.000      3.250         1   2011-06-01
#
#        CohortMonth  Cohort_Year  Cohort_Month  Invoice_Year  Invoice_Month  \
# 458811  2011-01-01         2011             1          2011             11
# 311356  2010-12-01         2010            12          2011              8
# 320837  2011-06-01         2011             6          2011              9
# 345315  2011-09-01         2011             9          2011              9
# 449517  2011-03-01         2011             3          2011             11
# 326435  2010-12-01         2010            12          2011              9
# 468435  2011-05-01         2011             5          2011             11
# 122258  2011-03-01         2011             3          2011              3
# 374883  2010-12-01         2010            12          2011             10
# 216705  2010-12-01         2010            12          2011              6
#
#         index
# 458811     11
# 311356      9
# 320837      4
# 345315      1
# 449517      9
# 326435     10
# 468435      7
# 122258      1
# 374883     11
# 216705      7

# %% [markdown]
# ## Create 1st Cohort: User number & Retention Rate

# %% [markdown]
# ### i. Pivot Cohort and Cohort Retention

# %%
cohort_first = df_cohort.groupby(['CohortMonth', 'index'])['CustomerID'].nunique().reset_index()
pivot_first = cohort_first.pivot(index='CohortMonth', columns='index', values='CustomerID').round(1)
pivot_first
# Out:
# index            1       2       3       4       5       6       7       8   \
# CohortMonth
# 2010-12-01  815.000 289.000 263.000 304.000 293.000 323.000 291.000 278.000
# 2011-01-01  358.000  76.000  93.000  84.000 119.000  99.000  90.000  87.000
# 2011-02-01  340.000  64.000  66.000  97.000  98.000  86.000  87.000  96.000
# 2011-03-01  419.000  64.000 109.000  83.000  94.000  69.000 111.000  96.000
# 2011-04-01  277.000  58.000  56.000  60.000  56.000  61.000  61.000  73.000
# 2011-05-01  256.000  48.000  44.000  44.000  53.000  58.000  68.000  23.000
# 2011-06-01  214.000  38.000  31.000  51.000  51.000  69.000  21.000     NaN
# 2011-07-01  169.000  30.000  33.000  39.000  47.000  18.000     NaN     NaN
# 2011-08-01  141.000  32.000  32.000  34.000  17.000     NaN     NaN     NaN
# 2011-09-01  276.000  63.000  83.000  32.000     NaN     NaN     NaN     NaN
# 2011-10-01  324.000  79.000  36.000     NaN     NaN     NaN     NaN     NaN
# 2011-11-01  298.000  35.000     NaN     NaN     NaN     NaN     NaN     NaN
# 2011-12-01   34.000     NaN     NaN     NaN     NaN     NaN     NaN     NaN
#
# index            9       10      11      12      13
# CohortMonth
# 2010-12-01  289.000 325.000 299.000 405.000 218.000
# 2011-01-01  108.000 117.000 127.000  43.000     NaN
# 2011-02-01   90.000 104.000  25.000     NaN     NaN
# 2011-03-01  119.000  38.000     NaN     NaN     NaN
# 2011-04-01   20.000     NaN     NaN     NaN     NaN
# 2011-05-01      NaN     NaN     NaN     NaN     NaN
# 2011-06-01      NaN     NaN     NaN     NaN     NaN
# 2011-07-01      NaN     NaN     NaN     NaN     NaN
# 2011-08-01      NaN     NaN     NaN     NaN     NaN
# 2011-09-01      NaN     NaN     NaN     NaN     NaN
# 2011-10-01      NaN     NaN     NaN     NaN     NaN
# 2011-11-01      NaN     NaN     NaN     NaN     NaN
# 2011-12-01      NaN     NaN     NaN     NaN     NaN

# %%
sizes = pivot_first.iloc[:,0]
retention = pivot_first.divide(sizes, axis=0).round(3)*100
retention
# Out:
# index            1      2      3      4      5      6      7      8      9   \
# CohortMonth
# 2010-12-01  100.000 35.500 32.300 37.300 36.000 39.600 35.700 34.100 35.500
# 2011-01-01  100.000 21.200 26.000 23.500 33.200 27.700 25.100 24.300 30.200
# 2011-02-01  100.000 18.800 19.400 28.500 28.800 25.300 25.600 28.200 26.500
# 2011-03-01  100.000 15.300 26.000 19.800 22.400 16.500 26.500 22.900 28.400
# 2011-04-01  100.000 20.900 20.200 21.700 20.200 22.000 22.000 26.400  7.200
# 2011-05-01  100.000 18.800 17.200 17.200 20.700 22.700 26.600  9.000    NaN
# 2011-06-01  100.000 17.800 14.500 23.800 23.800 32.200  9.800    NaN    NaN
# 2011-07-01  100.000 17.800 19.500 23.100 27.800 10.700    NaN    NaN    NaN
# 2011-08-01  100.000 22.700 22.700 24.100 12.100    NaN    NaN    NaN    NaN
# 2011-09-01  100.000 22.800 30.100 11.600    NaN    NaN    NaN    NaN    NaN
# 2011-10-01  100.000 24.400 11.100    NaN    NaN    NaN    NaN    NaN    NaN
# 2011-11-01  100.000 11.700    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 2011-12-01  100.000    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN
#
# index           10     11     12     13
# CohortMonth
# 2010-12-01  39.900 36.700 49.700 26.700
# 2011-01-01  32.700 35.500 12.000    NaN
# 2011-02-01  30.600  7.400    NaN    NaN
# 2011-03-01   9.100    NaN    NaN    NaN
# 2011-04-01     NaN    NaN    NaN    NaN
# 2011-05-01     NaN    NaN    NaN    NaN
# 2011-06-01     NaN    NaN    NaN    NaN
# 2011-07-01     NaN    NaN    NaN    NaN
# 2011-08-01     NaN    NaN    NaN    NaN
# 2011-09-01     NaN    NaN    NaN    NaN
# 2011-10-01     NaN    NaN    NaN    NaN
# 2011-11-01     NaN    NaN    NaN    NaN
# 2011-12-01     NaN    NaN    NaN    NaN

# %% [markdown]
# ### ii. Visualize analysis of cohort 1 using seaborn and matplotlib modules

# %%
plt.figure(figsize=(12,8))
plt.title('Retention Rate')
sns.heatmap(data=retention, annot=True, cmap='Greens', fmt='g')
# Out:
# <AxesSubplot:title={'center':'Retention Rate'}, xlabel='index', ylabel='CohortMonth'>

# %% [markdown]
# ## Create the 2nd Cohort: Average Quantity Sold

# %% [markdown]
# ### i. Pivot Cohort and Cohort Retention

# %%
cohort_second = df_cohort.groupby(['CohortMonth', 'index'])['Quantity'].mean().reset_index()
pivot_second = cohort_second.pivot(index='CohortMonth', columns='index', values='Quantity').round(1)
pivot_second
#ortalama satilan miktar
# Out:
# index           1      2      3      4      5      6      7       8      9   \
# CohortMonth
# 2010-12-01  11.400 12.900 13.900 13.900 13.300 13.300 14.300  13.800 16.100
# 2011-01-01  18.100  9.600  9.400 15.100 10.100 10.900 13.600  10.800 10.800
# 2011-02-01  11.000 14.000 15.900 12.100 12.300 11.900 13.900  13.700 11.000
# 2011-03-01   9.700 11.400 13.300 10.100 13.500 12.800 13.100  14.100 11.200
# 2011-04-01  10.100 10.200  9.700 11.900 11.900  8.300  9.900   9.400  7.500
# 2011-05-01  10.700  9.400 14.800 12.800 11.000  8.300 10.800 126.900    NaN
# 2011-06-01   9.500 14.800 12.000 12.700  9.800  8.900  9.400     NaN    NaN
# 2011-07-01  10.100 15.000  6.600  8.100  5.800  6.700    NaN     NaN    NaN
# 2011-08-01   9.400  6.000  5.000  5.900  6.600    NaN    NaN     NaN    NaN
# 2011-09-01  11.900  6.100  7.900  9.000    NaN    NaN    NaN     NaN    NaN
# 2011-10-01   8.700  7.200  8.200    NaN    NaN    NaN    NaN     NaN    NaN
# 2011-11-01   9.000  9.500    NaN    NaN    NaN    NaN    NaN     NaN    NaN
# 2011-12-01  15.700    NaN    NaN    NaN    NaN    NaN    NaN     NaN    NaN
#
# index           10     11     12     13
# CohortMonth
# 2010-12-01  16.100 16.700 12.400 14.500
# 2011-01-01   8.700  8.600 10.000    NaN
# 2011-02-01  12.500 13.800    NaN    NaN
# 2011-03-01   9.700    NaN    NaN    NaN
# 2011-04-01     NaN    NaN    NaN    NaN
# 2011-05-01     NaN    NaN    NaN    NaN
# 2011-06-01     NaN    NaN    NaN    NaN
# 2011-07-01     NaN    NaN    NaN    NaN
# 2011-08-01     NaN    NaN    NaN    NaN
# 2011-09-01     NaN    NaN    NaN    NaN
# 2011-10-01     NaN    NaN    NaN    NaN
# 2011-11-01     NaN    NaN    NaN    NaN
# 2011-12-01     NaN    NaN    NaN    NaN

# %% [markdown]
# ### ii. Visualize analysis of cohort 2 using seaborn and matplotlib modules

# %%
plt.figure(figsize=(12,8))
plt.title('Average Quantity')
sns.heatmap(data=pivot_second, annot=True, cmap='Greens', fmt='g')
# Out:
# <AxesSubplot:title={'center':'Average Quantity'}, xlabel='index', ylabel='CohortMonth'>

# %% [markdown]
# ## Create the 3rd Cohort: Average Sales

# %%
df_cohort['Total_Price'] = df_cohort['Quantity']* df_cohort['UnitPrice']

# %% [markdown]
# ### i. Pivot Cohort and Cohort Retention

# %%
cohort_third = df_cohort.groupby(['CohortMonth', 'index'])['Total_Price'].mean().reset_index()
pivot_third = cohort_third.pivot(index='CohortMonth', columns='index', values='Total_Price').round(1)
pivot_third
# Out:
# index           1      2      3      4      5      6      7       8      9   \
# CohortMonth
# 2010-12-01  21.200 22.400 24.000 23.800 20.200 25.800 26.000  23.900 26.200
# 2011-01-01  26.700 18.800 15.400 28.200 18.600 19.100 24.200  17.800 17.800
# 2011-02-01  17.000 20.100 19.400 19.200 17.600 16.100 21.300  23.000 18.200
# 2011-03-01  16.700 20.200 22.700 17.700 20.600 18.400 20.700  19.800 16.500
# 2011-04-01  16.600 20.100 19.200 18.700 19.100 14.100 14.900  15.300 11.500
# 2011-05-01  18.100 17.000 22.000 21.100 18.700 13.500 16.700 261.800    NaN
# 2011-06-01  22.900 15.200 19.600 16.600 13.300 13.300 12.700     NaN    NaN
# 2011-07-01  14.900 24.700 10.300 12.900  9.300  9.400    NaN     NaN    NaN
# 2011-08-01  15.200 13.000 12.100 15.600 17.100    NaN    NaN     NaN    NaN
# 2011-09-01  18.300 11.500 13.700 14.000    NaN    NaN    NaN     NaN    NaN
# 2011-10-01  13.500 11.100 13.800    NaN    NaN    NaN    NaN     NaN    NaN
# 2011-11-01  11.800 13.100    NaN    NaN    NaN    NaN    NaN     NaN    NaN
# 2011-12-01  29.400    NaN    NaN    NaN    NaN    NaN    NaN     NaN    NaN
#
# index           10     11     12     13
# CohortMonth
# 2010-12-01  31.500 31.100 21.700 24.500
# 2011-01-01  17.100 18.000 19.000    NaN
# 2011-02-01  22.000 23.900    NaN    NaN
# 2011-03-01  13.100    NaN    NaN    NaN
# 2011-04-01     NaN    NaN    NaN    NaN
# 2011-05-01     NaN    NaN    NaN    NaN
# 2011-06-01     NaN    NaN    NaN    NaN
# 2011-07-01     NaN    NaN    NaN    NaN
# 2011-08-01     NaN    NaN    NaN    NaN
# 2011-09-01     NaN    NaN    NaN    NaN
# 2011-10-01     NaN    NaN    NaN    NaN
# 2011-11-01     NaN    NaN    NaN    NaN
# 2011-12-01     NaN    NaN    NaN    NaN

# %% [markdown]
# ### ii. Visualize analysis of cohort 3 using seaborn and matplotlib modules

# %%
plt.figure(figsize=(12,8))
plt.title('Retention Rates')
sns.heatmap(data=pivot_third, annot=True, cmap='Greens')
# Out:
# <AxesSubplot:title={'center':'Retention Rates'}, xlabel='index', ylabel='CohortMonth'>

# %% [markdown]
# # Conclus

# %% [markdown]
# For e-commerce organisations, cohort analysis is a unique opportunity to find out which clients are the most valuable to their business. by performing Cohort analysis you can get answers to following questions:
#
# - How much effective was a marketing campaign held in a particular time period?
# - Did the strategy employed to improve the conversion rates of Customers worked?
# - Should I focus more on retention rather than acquiring new customers?
# - Are my customer nurturing strategies effective?
# - Which marketing channels bring me the best results?
# - Is there a seasoanlity pattern in Customer behahiour?

# %% [markdown]
# ___
#
# <p style="text-align: center;"><img src="https://docs.google.com/uc?id=1lY0Uj5R04yMY3-ZppPWxqCr5pvBLYPnV" class="img-fluid" alt="CLRSWY"></p>
#
# ___
